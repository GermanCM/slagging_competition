# %% [markdown]
# ## Inside a Boiler - Slagging Prediction
# #### https://opendata.edp.com/pages/challenges/#description

# %%
### Chec#from imblearn.combine import SMOTETomek
import pandas as pd 
import numpy as np 
from numpy import sort, sqrt, argsort, inf
from sklearn.feature_selection import SelectFromModel

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, KFold

from sklearn.metrics import precision_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer, precision_recall_curve,confusion_matrix
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier

# %%
data_unit_y_year_2 = pd.read_csv('..\\data\\boiler_unity_xxx2.csv',sep=';')

# %% [markdown]
# ### Check: hay variables de temperatura que, según la literatura, podrían ser altamente informativas?

# %%
temperature_columns_mask = ['temperature' in x for x in data_unit_y_year_2.columns]
data_unit_y_year_2.columns[temperature_columns_mask]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### Eliminamos variables altamente correladas entre sí

# %%
import pandas_profiling

df_profile = pandas_profiling.ProfileReport(data_unit_y_year_2.iloc[:50])
df_profile.to_widgets()

# %%
'''
    En base a las correlaciones obtenidas en el profiling:
    - añado 'Boiler_Feedwater_Pressure'
    - elimino los cold primary air y me quedo con los hot primary air
    - añado 'Air Heater #1 Differential Pressure'
    - elimino 'Total_Boiler_Feedwater_Flow'
    - elimino los Flue gas damper position: por algo de experiencia, los valores que indican 
      posiciones de accionamientos no suelen informar de estados de procesos; además, el histograma de valores
      más anómalos (entre 0 y 10) no se dan en torno a las fechas de slag
    - 

'''
'''
selected_colums_yirman = ['SSTIMESTAMP',
'Active_Power',
'Boiler_Feedwater_Pressure',
'Boiler_Furnace_Pressure',
'Boiler_Outlet_Pressure',
'Coal_Feeder_#1',
'Coal_Feeder_#5',
'Dynamic_Coal_Classifier_Rotational_Speed_Coal_Mill_#1',
'Dynamic_Coal_Classifier_Rotational_Speed_Coal_Mill_#2',
'Dynamic_Coal_Classifier_Rotational_Speed_Coal_Mill_#3',
'Secondary_Air_Row_#3_(Side_2)',
'Secondary_Air_Row_#5_(Side_2)',
'Boosted_Overfire_Air_(Side_1)',
'Boosted_Overfire_Air_(Side_2)',
'Secondary_Air_Fan_#1_Temperature_2',
'Flue_Gas_Induced_Draft_Fan_#1_Blade_Pitch_Angle',
'Total_Atemperator_Feedwater_Flow',
'Main_Steam_First_Desuperheater_Control_Valve_position_(Side_1)',
'Main_Steam_First_Desuperheater_Control_Valve_position_(Side_2)',
'Main_Steam_Second_Desuperheater_Control_Valve_position_(Side_1)',
'Main_Steam_Second_Desuperheater_Control_Valve_position_(Side_2)',
'Main_Steam_Turbine_Control_Valve_#B',
'Main_Steam_Turbine_Control_Valve_#D',
'Air_Heater_#1_Differential_Pressure',
'Reheated_Steam_Temperature_1_@Outlet']
'''
selected_colums_yirman = ['SSTIMESTAMP',
'Active Power',
'Boiler Feedwater Pressure',
'Boiler Furnace Pressure',
'Boiler Outlet Pressure',
'Coal Feeder #1',
'Coal Feeder #5',
'Dynamic Coal Classifier Rotational Speed Coal Mill #1',
'Dynamic Coal Classifier Rotational Speed Coal Mill #2',
'Dynamic Coal Classifier Rotational Speed Coal Mill #3',
'Secondary Air Row #3 (Side 2)',
'Secondary Air Row #5 (Side 2)',
'Boosted Overfire Air (Side 1)',
'Boosted Overfire Air (Side 2)',
'Secondary Air Fan #1 Temperature 2',
'Flue Gas Induced Draft Fan #1 Blade Pitch Angle',
'Total Atemperator Feedwater Flow',
'Main Steam First Desuperheater Control Valve position (Side 1)',
'Main Steam First Desuperheater Control Valve position (Side 2)',
'Main Steam Second Desuperheater Control Valve position (Side 1)',
'Main Steam Second Desuperheater Control Valve position (Side 2)',
'Main Steam Turbine Control Valve #B',
'Main Steam Turbine Control Valve #D',
'Air Heater #1 Differential Pressure',
'Reheated Steam Temperature 1 @Outlet']

data = data_unit_y_year_2[selected_colums_yirman]

# %%
'''
data = data[selected_colums_yirman]
na_cols = [x for x in data.columns if x in data.columns[data.isnull().any()].tolist()]
for col in na_cols:
    data[col] = data[col].fillna(data[col].mean())
'''
#%%
def q10(x):
    return x.quantile(0.1)

# %% [markdown]
# ### Para sampleo diario

# %%
'''
### Feature engineering: 
### 1.- en base a atributos estadísticos en sampleo diario
## ToDo:
### 2.- igual pero con otro sampling frequency
### 3.- añadiendo atributo de tendencias y/o estacionalidad
### 4.- TSFresh

unique_ID_values = data['ID'].unique()
unique_days = [x.split('-')[0] for x in unique_ID_values]
unique_months = [x.split('-')[1] for x in unique_ID_values]

tablon_final = pd.DataFrame({'ID': unique_ID_values, 'DAY': unique_days, 'MONTH': unique_months})
features = [x for x in data.columns if x not in ['TIME', 'HOUR', 'DAY', 'MONTH', 'ID']]
for col in features:
    #AÑADIR MEAN Y MEDIAN EXPONENTIALLY WEIGHTED
    prueba = data.groupby(['ID'])[col].agg(['count','mean','max','min','std','skew',q10]).reset_index(drop=True)
    prueba = prueba.add_prefix(col+'_')
    tablon_final = pd.concat([tablon_final, prueba],axis=1)
'''
# Out:
# "\n### Feature engineering: \n### 1.- en base a atributos estadísticos en sampleo diario\n## ToDo:\n### 2.- igual pero con otro sampling frequency\n### 3.- añadiendo atributo de tendencias y/o estacionalidad\n### 4.- TSFresh\n\nunique_ID_values = data['ID'].unique()\nunique_days = [x.split('-')[0] for x in unique_ID_values]\nunique_months = [x.split('-')[1] for x in unique_ID_values]\n\ntablon_final = pd.DataFrame({'ID': unique_ID_values, 'DAY': unique_days, 'MONTH': unique_months})\nfeatures = [x for x in data.columns if x not in ['TIME', 'HOUR', 'DAY', 'MONTH', 'ID']]\nfor col in features:\n    #AÑADIR MEAN Y MEDIAN EXPONENTIALLY WEIGHTED\n    prueba = data.groupby(['ID'])[col].agg(['count','mean','max','min','std','skew',q10]).reset_index(drop=True)\n    prueba = prueba.add_prefix(col+'_')\n    tablon_final = pd.concat([tablon_final, prueba],axis=1)\n"

# %% [markdown]
# ### Para sampleo horario <font color='red'> (probar también con resampleo cada 4 horas por ejemplo) </font>

# %%
data['SSTIMESTAMP'][:3]
# Out:
# 0    07-05-xxx2 18:40:00
# 1    07-05-xxx2 18:45:00
# 2    07-05-xxx2 18:50:00
# Name: SSTIMESTAMP, dtype: object

# %% [markdown]
# ### Creamos atributo ID con la combinación de mes+día+hora

# %%
datetime_values = data['SSTIMESTAMP']
hours_values = pd.Series([x.split(' ')[1].split(':')[0] for x in datetime_values]) 
days_values = pd.Series([x.split(' ')[0].split('-')[0] for x in datetime_values])
months_values = pd.Series([x.split(' ')[0].split('-')[1] for x in datetime_values])

frequency_sampling_ID = list([months_values[0]+'-'+days_values[0]+'-'+hours_values[0]])
for index in range(1, len(hours_values)):
    frequency_sampling_ID.append(months_values[index]+'-'+days_values[index]+'-'+hours_values[index])
data['ID_sampling'] = frequency_sampling_ID

# %% [markdown]
# ### Check: cada agrupación por ID_sampling debe contener 12 elementos (12 packs de 5 min por hora)

# %%
data.groupby(['ID_sampling'])['SSTIMESTAMP'].agg(['count'])
# Out:
#              count
# ID_sampling
# 01-01-00        12
# 01-01-01        12
# 01-01-02        12
# 01-01-03        12
# 01-01-04        12
# ...            ...
# 12-31-19        12
# 12-31-20        12
# 12-31-21        12
# 12-31-22        12
# 12-31-23        12
#
# [8759 rows x 1 columns]

# %%
data.head(5)
data.tail(5)
# Out:
#                 SSTIMESTAMP  Active Power  Boiler Feedwater Pressure  \
# 105115  31-12-xxx2 12:55:00      0.964155                   206.4453
# 105116  31-12-xxx2 13:10:00      0.964846                   206.2500
# 105117  31-12-xxx2 13:20:00      0.965294                   206.2500
# 105118  31-12-xxx2 13:25:00      0.965500                   206.2500
# 105119  31-12-xxx2 13:55:00      0.966511                   206.7383
#
#         Boiler Furnace Pressure  Boiler Outlet Pressure  Coal Feeder #1  \
# 105115                -0.761719               -8.789063        30.70313
# 105116                -0.878906               -8.984375        30.75195
# 105117                -0.761719               -8.847656        30.54688
# 105118                -0.546875               -8.652344        30.60547
# 105119                -0.820312               -8.886719        30.79102
#
#         Coal Feeder #5  Dynamic Coal Classifier Rotational Speed Coal Mill #1  \
# 105115        30.79102                                           100.1465
# 105116        30.91797                                           100.1465
# 105117        30.74219                                           100.1465
# 105118        30.89844                                           100.1465
# 105119        30.87891                                           100.1465
#
#         Dynamic Coal Classifier Rotational Speed Coal Mill #2  \
# 105115                                          -0.292969
# 105116                                          -0.292969
# 105117                                          -0.292969
# 105118                                          -0.292969
# 105119                                          -0.292969
#
#         Dynamic Coal Classifier Rotational Speed Coal Mill #3  ...  \
# 105115                                           86.42578      ...
# 105116                                           85.88867      ...
# 105117                                           85.74219      ...
# 105118                                           86.42578      ...
# 105119                                           86.42578      ...
#
#         Total Atemperator Feedwater Flow  \
# 105115                          36.38478
# 105116                          36.00537
# 105117                          36.76028
# 105118                          36.38478
# 105119                          34.20591
#
#         Main Steam First Desuperheater Control Valve position (Side 1)  \
# 105115                                           0.390625
# 105116                                           0.439453
# 105117                                           0.439453
# 105118                                           0.439453
# 105119                                           0.610352
#
#         Main Steam First Desuperheater Control Valve position (Side 2)  \
# 105115                                           21.94824
# 105116                                           21.89941
# 105117                                           22.80273
# 105118                                           22.55859
# 105119                                           20.62988
#
#         Main Steam Second Desuperheater Control Valve position (Side 1)  \
# 105115                                           24.43848
# 105116                                           19.31152
# 105117                                           19.23828
# 105118                                           20.04395
# 105119                                           20.36133
#
#         Main Steam Second Desuperheater Control Valve position (Side 2)  \
# 105115                                           40.89355
# 105116                                           41.96777
# 105117                                           41.25977
# 105118                                           35.69336
# 105119                                           36.81641
#
#         Main Steam Turbine Control Valve #B  \
# 105115                             105.5673
# 105116                             105.4666
# 105117                             105.7184
# 105118                             105.7184
# 105119                             105.5170
#
#         Main Steam Turbine Control Valve #D  \
# 105115                             37.35439
# 105116                             39.04653
# 105117                             39.86343
# 105118                             40.03848
# 105119                             44.06460
#
#         Air Heater #1 Differential Pressure  \
# 105115                             16.23535
# 105116                             16.30859
# 105117                             16.29639
# 105118                             16.36353
# 105119                             16.48560
#
#         Reheated Steam Temperature 1 @Outlet  ID_sampling
# 105115                              526.6379     12-31-12
# 105116                              526.6379     12-31-13
# 105117                              526.6379     12-31-13
# 105118                              527.2504     12-31-13
# 105119                              527.2504     12-31-13
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Statistical features engineering

# %%
### Feature engineering: 
### 1.- en base a atributos estadísticos en sampleo horario
## ToDo:
### 2.- igual pero con otro sampling frequency
### 3.- añadiendo atributo de tendencias y/o estacionalidad
### 4.- TSFresh

tablon_final = pd.DataFrame({'ID_sampling': frequency_sampling_ID, 'HOUR': hours_values, 'DAY': days_values, 'MONTH': months_values})
tablon_final.drop_duplicates(subset='ID_sampling', keep='first', inplace=True)
tablon_final.set_index('ID_sampling', inplace=True)

features = [x for x in data.columns if x not in ['ID_sampling', 'HOUR', 'DAY', 'MONTH', 'SSTIMESTAMP']]

for col in features:
    #AÑADIR MEAN Y MEDIAN EXPONENTIALLY WEIGHTED
    data_hourly_grouped = data.groupby(['ID_sampling'])[col].agg(['median','mean','max','min','std','skew']).reset_index(drop=True)
    data_hourly_grouped = data_hourly_grouped.add_prefix(col+'_')
    data_hourly_grouped.index = tablon_final.index
    tablon_final = pd.concat([tablon_final, data_hourly_grouped],axis=1)

# %%
tablon_final.head(5)
# Out:
#             HOUR DAY MONTH  Active Power_median  Active Power_mean  \
# ID_sampling
# 05-07-18      18  07    05             0.969362           0.969339
# 05-07-19      19  07    05             0.968115           0.968051
# 05-07-20      20  07    05             0.967400           0.967584
# 05-07-21      21  07    05             0.968011           0.968120
# 05-07-22      22  07    05             0.968090           0.968190
#
#              Active Power_max  Active Power_min  Active Power_std  \
# ID_sampling
# 05-07-18             0.974776          0.964863          0.002600
# 05-07-19             0.969804          0.965298          0.001423
# 05-07-20             0.970033          0.964842          0.001625
# 05-07-21             0.971448          0.964927          0.001766
# 05-07-22             0.973212          0.964162          0.002647
#
#              Active Power_skew  Boiler Feedwater Pressure_median  ...  \
# ID_sampling                                                       ...
# 05-07-18              0.221930                         208.74025  ...
# 05-07-19             -0.489962                         208.69140  ...
# 05-07-20             -0.120457                         208.39840  ...
# 05-07-21              0.112577                         208.39840  ...
# 05-07-22              0.461466                         207.81250  ...
#
#              Air Heater #1 Differential Pressure_max  \
# ID_sampling
# 05-07-18                                    12.92114
# 05-07-19                                    12.67090
# 05-07-20                                    12.59155
# 05-07-21                                    12.55493
# 05-07-22                                    12.69531
#
#              Air Heater #1 Differential Pressure_min  \
# ID_sampling
# 05-07-18                                    12.45728
# 05-07-19                                    12.46338
# 05-07-20                                    12.42676
# 05-07-21                                    12.40845
# 05-07-22                                    12.39014
#
#              Air Heater #1 Differential Pressure_std  \
# ID_sampling
# 05-07-18                                    0.128844
# 05-07-19                                    0.061881
# 05-07-20                                    0.058260
# 05-07-21                                    0.050158
# 05-07-22                                    0.102034
#
#              Air Heater #1 Differential Pressure_skew  \
# ID_sampling
# 05-07-18                                    -1.504877
# 05-07-19                                     0.280133
# 05-07-20                                    -0.454415
# 05-07-21                                     0.093290
# 05-07-22                                     0.093195
#
#              Reheated Steam Temperature 1 @Outlet_median  \
# ID_sampling
# 05-07-18                                       530.71995
# 05-07-19                                       529.65580
# 05-07-20                                       530.31420
# 05-07-21                                       529.44605
# 05-07-22                                       529.69830
#
#              Reheated Steam Temperature 1 @Outlet_mean  \
# ID_sampling
# 05-07-18                                    530.865042
# 05-07-19                                    529.748775
# 05-07-20                                    530.438350
# 05-07-21                                    529.677217
# 05-07-22                                    528.985675
#
#              Reheated Steam Temperature 1 @Outlet_max  \
# ID_sampling
# 05-07-18                                     531.9487
# 05-07-19                                     530.2197
# 05-07-20                                     530.8199
# 05-07-21                                     530.3142
# 05-07-22                                     529.6983
#
#              Reheated Steam Temperature 1 @Outlet_min  \
# ID_sampling
# 05-07-18                                     530.2197
# 05-07-19                                     529.6558
# 05-07-20                                     530.2076
# 05-07-21                                     529.1327
# 05-07-22                                     526.1230
#
#              Reheated Steam Temperature 1 @Outlet_std  \
# ID_sampling
# 05-07-18                                     0.443263
# 05-07-19                                     0.217158
# 05-07-20                                     0.285210
# 05-07-21                                     0.588873
# 05-07-22                                     1.395905
#
#              Reheated Steam Temperature 1 @Outlet_skew
# ID_sampling
# 05-07-18                                      1.384931
# 05-07-19                                      2.055890
# 05-07-20                                      0.728890
# 05-07-21                                      0.173163
# 05-07-22                                     -1.764220
#
# [5 rows x 147 columns]

# %% [markdown]
# ### Se añaden atributos temporales y se ordena por mes, día y hora

# %%
tablon_final.MONTH = tablon_final.MONTH.astype('int32')
tablon_final.DAY = tablon_final.DAY.astype('int32')
tablon_final.HOUR = tablon_final.HOUR.astype('int32')

tablon_final.sort_values(by=['MONTH', 'DAY', 'HOUR'], ascending=[1, 1, 1], inplace=True)

tablon_final.tail()
# Out:
#              HOUR  DAY  MONTH  Active Power_median  Active Power_mean  \
# ID_sampling
# 12-31-19       19   31     12             0.327980           0.328251
# 12-31-20       20   31     12             0.325991           0.329366
# 12-31-21       21   31     12             0.326058           0.325015
# 12-31-22       22   31     12             0.325684           0.325704
# 12-31-23       23   31     12             0.631711           0.581360
#
#              Active Power_max  Active Power_min  Active Power_std  \
# ID_sampling
# 12-31-19             0.329503          0.327614          0.000622
# 12-31-20             0.346467          0.322904          0.008539
# 12-31-21             0.327282          0.317474          0.002718
# 12-31-22             0.334341          0.316690          0.003811
# 12-31-23             0.725705          0.321537          0.142511
#
#              Active Power_skew  Boiler Feedwater Pressure_median  ...  \
# ID_sampling                                                       ...
# 12-31-19              1.038830                         189.35550  ...
# 12-31-20              1.514106                         189.45310  ...
# 12-31-21             -2.362497                         189.69725  ...
# 12-31-22             -0.171542                         189.45310  ...
# 12-31-23             -0.661629                         192.43165  ...
#
#              Air Heater #1 Differential Pressure_max  \
# ID_sampling
# 12-31-19                                    7.507324
# 12-31-20                                    8.392334
# 12-31-21                                    7.489014
# 12-31-22                                    7.531738
# 12-31-23                                   12.188720
#
#              Air Heater #1 Differential Pressure_min  \
# ID_sampling
# 12-31-19                                    7.440186
# 12-31-20                                    7.354736
# 12-31-21                                    7.354736
# 12-31-22                                    6.384277
# 12-31-23                                    7.043457
#
#              Air Heater #1 Differential Pressure_std  \
# ID_sampling
# 12-31-19                                    0.030499
# 12-31-20                                    0.284228
# 12-31-21                                    0.043585
# 12-31-22                                    0.398307
# 12-31-23                                    1.606534
#
#              Air Heater #1 Differential Pressure_skew  \
# ID_sampling
# 12-31-19                                     0.707223
# 12-31-20                                     3.410435
# 12-31-21                                    -1.481554
# 12-31-22                                    -2.044275
# 12-31-23                                    -0.007160
#
#              Reheated Steam Temperature 1 @Outlet_median  \
# ID_sampling
# 12-31-19                                        503.3811
# 12-31-20                                        503.7989
# 12-31-21                                        503.2954
# 12-31-22                                        503.2954
# 12-31-23                                        510.0666
#
#              Reheated Steam Temperature 1 @Outlet_mean  \
# ID_sampling
# 12-31-19                                    503.111142
# 12-31-20                                    504.047567
# 12-31-21                                    503.295400
# 12-31-22                                    503.393600
# 12-31-23                                    513.553708
#
#              Reheated Steam Temperature 1 @Outlet_max  \
# ID_sampling
# 12-31-19                                     503.9383
# 12-31-20                                     505.1213
# 12-31-21                                     503.2954
# 12-31-22                                     503.8846
# 12-31-23                                     526.8130
#
#              Reheated Steam Temperature 1 @Outlet_min  \
# ID_sampling
# 12-31-19                                     502.2818
# 12-31-20                                     503.2954
# 12-31-21                                     503.2954
# 12-31-22                                     503.2954
# 12-31-23                                     502.7367
#
#              Reheated Steam Temperature 1 @Outlet_std  \
# ID_sampling
# 12-31-19                                     0.597675
# 12-31-20                                     0.565929
# 12-31-21                                     0.000000
# 12-31-22                                     0.229346
# 12-31-23                                    10.079683
#
#              Reheated Steam Temperature 1 @Outlet_skew
# ID_sampling
# 12-31-19                                     -0.263358
# 12-31-20                                      1.224989
# 12-31-21                                      0.000000
# 12-31-22                                      2.055237
# 12-31-23                                      0.434543
#
# [5 rows x 147 columns]

# %% [markdown]
# ## Añadimos los días que preceden al efecto de slag

# %%
### El resto de días no nos preocupa, ya que caeríamos dentro de los falsos positivos 
warning_window_dates = ['01-08', '02-08', '03-08', '04-08', '05-08', '06-08', '07-08', '08-08', '09-08',
                        '10-08', '11-08', '12-08', '13-08', '14-08', '15-08', '16-08', '17-08', '18-08', '19-08',
                        '20-08', '21-08', '22-08', '23-08', '24-08', '25-08', '26-08', '27-08', '28-08', '29-08', '30-08']

# %%
# el slagging day registrado para el boiler 3 en el año 3 es: 3-11-XXX3
slag_day_reference = 37 #(30 días de agosto + 7 de septiembre como referencia)
tablon_final['DAYS_TILL_SLAG'] = 0 

for date in warning_window_dates: 
    warning_month = int(date.split('-')[1])
    warning_day = int(date.split('-')[0])
    
    tablon_final['DAYS_TILL_SLAG'] = \
        np.where(((tablon_final.MONTH==warning_month)&(tablon_final.DAY==warning_day)),slag_day_reference-warning_day,
                   tablon_final['DAYS_TILL_SLAG'])

# %%
tablon_final[tablon_final.DAYS_TILL_SLAG>0]
# Out:
#              HOUR  DAY  MONTH  Active Power_median  Active Power_mean  \
# ID_sampling
# 08-01-00        0    1      8             0.958815           0.959237
# 08-01-01        1    1      8             0.966662           0.966490
# 08-01-02        2    1      8             0.965354           0.965678
# 08-01-03        3    1      8             0.965793           0.966515
# 08-01-04        4    1      8             0.965922           0.966124
# ...           ...  ...    ...                  ...                ...
# 08-30-19       19   30      8             0.971278           0.971337
# 08-30-20       20   30      8             0.971595           0.971354
# 08-30-21       21   30      8             0.972455           0.973266
# 08-30-22       22   30      8             0.976487           0.976122
# 08-30-23       23   30      8             0.974744           0.974646
#
#              Active Power_max  Active Power_min  Active Power_std  \
# ID_sampling
# 08-01-00             0.965213          0.956246          0.002301
# 08-01-01             0.969262          0.962819          0.002109
# 08-01-02             0.968457          0.964219          0.001413
# 08-01-03             0.970724          0.963586          0.002378
# 08-01-04             0.973140          0.959403          0.003500
# ...                       ...               ...               ...
# 08-30-19             0.974060          0.967401          0.002018
# 08-30-20             0.974626          0.967987          0.001951
# 08-30-21             0.980030          0.970104          0.002906
# 08-30-22             0.981954          0.971611          0.002346
# 08-30-23             0.976487          0.972384          0.001722
#
#              Active Power_skew  Boiler Feedwater Pressure_median  ...  \
# ID_sampling                                                       ...
# 08-01-00              1.609777                          206.7383  ...
# 08-01-01             -0.406362                          208.3008  ...
# 08-01-02              1.170853                          208.3496  ...
# 08-01-03              0.800437                          208.4961  ...
# 08-01-04              0.152811                          208.3008  ...
# ...                        ...                               ...  ...
# 08-30-19             -0.428993                          207.0313  ...
# 08-30-20             -0.028404                          206.6406  ...
# 08-30-21              1.392269                          206.7871  ...
# 08-30-22              0.822606                          206.9336  ...
# 08-30-23             -0.267685                          206.6406  ...
#
#              Air Heater #1 Differential Pressure_min  \
# ID_sampling
# 08-01-00                                   15.411380
# 08-01-01                                   12.902830
# 08-01-02                                   12.896730
# 08-01-03                                   12.701420
# 08-01-04                                   12.750240
# ...                                              ...
# 08-30-19                                    9.613037
# 08-30-20                                    9.747314
# 08-30-21                                    9.759521
# 08-30-22                                   10.015870
# 08-30-23                                   10.107420
#
#              Air Heater #1 Differential Pressure_std  \
# ID_sampling
# 08-01-00                                    0.094032
# 08-01-01                                    0.060861
# 08-01-02                                    0.046733
# 08-01-03                                    0.104760
# 08-01-04                                    0.043925
# ...                                              ...
# 08-30-19                                    0.063667
# 08-30-20                                    0.041546
# 08-30-21                                    0.120070
# 08-30-22                                    0.109073
# 08-30-23                                    0.037923
#
#              Air Heater #1 Differential Pressure_skew  \
# ID_sampling
# 08-01-00                                     0.645404
# 08-01-01                                    -0.143082
# 08-01-02                                    -0.012644
# 08-01-03                                     0.860863
# 08-01-04                                     0.695853
# ...                                               ...
# 08-30-19                                    -0.007311
# 08-30-20                                     0.211384
# 08-30-21                                     0.615403
# 08-30-22                                     1.234729
# 08-30-23                                     0.306065
#
#              Reheated Steam Temperature 1 @Outlet_median  \
# ID_sampling
# 08-01-00                                       531.42760
# 08-01-01                                       531.71750
# 08-01-02                                       531.28370
# 08-01-03                                       531.89380
# 08-01-04                                       530.39990
# ...                                                  ...
# 08-30-19                                       531.84300
# 08-30-20                                       531.51495
# 08-30-21                                       530.55570
# 08-30-22                                       530.86100
# 08-30-23                                       530.73540
#
#              Reheated Steam Temperature 1 @Outlet_mean  \
# ID_sampling
# 08-01-00                                    531.443342
# 08-01-01                                    531.599175
# 08-01-02                                    531.468400
# 08-01-03                                    531.781642
# 08-01-04                                    530.312600
# ...                                                ...
# 08-30-19                                    531.738250
# 08-30-20                                    531.625325
# 08-30-21                                    530.596875
# 08-30-22                                    530.929233
# 08-30-23                                    530.442633
#
#              Reheated Steam Temperature 1 @Outlet_max  \
# ID_sampling
# 08-01-00                                     532.0732
# 08-01-01                                     532.0225
# 08-01-02                                     532.0225
# 08-01-03                                     532.5149
# 08-01-04                                     531.1095
# ...                                               ...
# 08-30-19                                     531.9158
# 08-30-20                                     532.4406
# 08-30-21                                     531.7551
# 08-30-22                                     532.1329
# 08-30-23                                     531.5443
#
#              Reheated Steam Temperature 1 @Outlet_min  \
# ID_sampling
# 08-01-00                                     530.9030
# 08-01-01                                     530.7657
# 08-01-02                                     531.2837
# 08-01-03                                     529.9268
# 08-01-04                                     528.6983
# ...                                               ...
# 08-30-19                                     531.1624
# 08-30-20                                     531.1624
# 08-30-21                                     529.6916
# 08-30-22                                     530.3427
# 08-30-23                                     529.0128
#
#              Reheated Steam Temperature 1 @Outlet_std  \
# ID_sampling
# 08-01-00                                     0.251114
# 08-01-01                                     0.491422
# 08-01-02                                     0.334135
# 08-01-03                                     0.610804
# 08-01-04                                     0.872933
# ...                                               ...
# 08-30-19                                     0.262558
# 08-30-20                                     0.485932
# 08-30-21                                     0.551928
# 08-30-22                                     0.620334
# 08-30-23                                     0.816487
#
#              Reheated Steam Temperature 1 @Outlet_skew  DAYS_TILL_SLAG
# ID_sampling
# 08-01-00                                      0.635346              36
# 08-01-01                                     -0.685063              36
# 08-01-02                                      1.326650              36
# 08-01-03                                     -2.859452              36
# 08-01-04                                     -0.713573              36
# ...                                                ...             ...
# 08-30-19                                     -2.027535               7
# 08-30-20                                      0.645462               7
# 08-30-21                                      0.592084               7
# 08-30-22                                      1.248474               7
# 08-30-23                                     -0.900006               7
#
# [720 rows x 148 columns]

# %% [markdown]
# ### Etiquetamos clases binarias.
#
# ### Posteriormente, etiqutado multiclase para dar mayor relevancia en las predicciones de nuestros positivos (efecto slag) a los registros etiquetados como 4, luego 3... ya que nuestra hipótesis es que el efecto debe ser más evidente en días más próximos al efecto slag, y esto es más avanzados en nuestro warning window

# %%
tablon_final['TARGET'] = 0

mask_label = (tablon_final.DAYS_TILL_SLAG < 30)&(tablon_final.DAYS_TILL_SLAG >= 9)
mask_indexes = tablon_final[mask_label].index 
tablon_final.loc[mask_indexes, 'TARGET'] = 1

# %%
tablon_final[tablon_final.TARGET>0][['MONTH', 'DAY', 'DAYS_TILL_SLAG', 'TARGET']]
# Out:
#              MONTH  DAY  DAYS_TILL_SLAG  TARGET
# ID_sampling
# 08-08-00         8    8              29       1
# 08-08-01         8    8              29       1
# 08-08-02         8    8              29       1
# 08-08-03         8    8              29       1
# 08-08-04         8    8              29       1
# ...            ...  ...             ...     ...
# 08-28-19         8   28               9       1
# 08-28-20         8   28               9       1
# 08-28-21         8   28               9       1
# 08-28-22         8   28               9       1
# 08-28-23         8   28               9       1
#
# [504 rows x 4 columns]

# %% [markdown]
# ### Construimos nuestro input attributes y el target

# %%
#inputs = [x for x in tablon_final.columns if x not in ['TARGET', 'DAYS_TILL_SLAG', 'HOUR', 'DAY', 'MONTH']]
inputs = [x for x in tablon_final.columns if x not in ['TARGET', 'HOUR', 'DAY', 'MONTH']]
X = tablon_final[inputs]
y = tablon_final['TARGET']

# %% [markdown]
# ### Interpolamos valores ausentes: método lineal para datos de sensores

# %%
def imputeMissingInterpolating(array_df, features_to_impute):
    import numpy as np
    for attr in features_to_impute:
        attribute_interpolated = array_df[attr].interpolate(method='linear', limit_direction='both')
        #print('nans length for {}: {}'.format(attr, len(attribute_interpolated[np.isnan(attribute_interpolated)])))
        assert len(attribute_interpolated[np.isnan(attribute_interpolated)]) == 0
        
        array_df[attr] = attribute_interpolated
    
    return array_df

X_interpolated = imputeMissingInterpolating(X, X.columns[X.isna().any()])
X_interpolated.head(3)
# Out:
#              Active Power_median  Active Power_mean  Active Power_max  \
# ID_sampling
# 01-01-00                0.964467           0.964946          0.971731
# 01-01-01                0.965041           0.965050          0.971931
# 01-01-02                0.964901           0.965084          0.967879
#
#              Active Power_min  Active Power_std  Active Power_skew  \
# ID_sampling
# 01-01-00             0.961250          0.002775           1.204164
# 01-01-01             0.959900          0.003187           0.669930
# 01-01-02             0.961571          0.001888          -0.322302
#
#              Boiler Feedwater Pressure_median  Boiler Feedwater Pressure_mean  \
# ID_sampling
# 01-01-00                             207.9102                      207.600925
# 01-01-01                             207.2754                      207.332367
# 01-01-02                             207.4219                      207.560217
#
#              Boiler Feedwater Pressure_max  Boiler Feedwater Pressure_min  \
# ID_sampling
# 01-01-00                          208.0078                       206.4453
# 01-01-01                          208.1055                       206.4453
# 01-01-02                          208.1055                       207.3242
#
#              ...  Air Heater #1 Differential Pressure_min  \
# ID_sampling  ...
# 01-01-00     ...                                 12.35962
# 01-01-01     ...                                 12.40234
# 01-01-02     ...                                 12.44507
#
#              Air Heater #1 Differential Pressure_std  \
# ID_sampling
# 01-01-00                                    0.085427
# 01-01-01                                    0.097996
# 01-01-02                                    0.075584
#
#              Air Heater #1 Differential Pressure_skew  \
# ID_sampling
# 01-01-00                                     0.558582
# 01-01-01                                    -0.275233
# 01-01-02                                     0.900881
#
#              Reheated Steam Temperature 1 @Outlet_median  \
# ID_sampling
# 01-01-00                                        530.9978
# 01-01-01                                        533.1464
# 01-01-02                                        533.0904
#
#              Reheated Steam Temperature 1 @Outlet_mean  \
# ID_sampling
# 01-01-00                                    531.264917
# 01-01-01                                    533.131875
# 01-01-02                                    532.903167
#
#              Reheated Steam Temperature 1 @Outlet_max  \
# ID_sampling
# 01-01-00                                     531.8762
# 01-01-01                                     533.6511
# 01-01-02                                     533.0904
#
#              Reheated Steam Temperature 1 @Outlet_min  \
# ID_sampling
# 01-01-00                                     530.4045
# 01-01-01                                     532.5592
# 01-01-02                                     532.4982
#
#              Reheated Steam Temperature 1 @Outlet_std  \
# ID_sampling
# 01-01-00                                     0.580417
# 01-01-01                                     0.234602
# 01-01-02                                     0.277173
#
#              Reheated Steam Temperature 1 @Outlet_skew  DAYS_TILL_SLAG
# ID_sampling
# 01-01-00                                     -0.126744               0
# 01-01-01                                     -0.407787               0
# 01-01-02                                     -0.828460               0
#
# [3 rows x 145 columns]

# %%
X_interpolated.columns[X_interpolated.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### Escalamos valores estandarizando: standard scaler

# %%
def scale_and_save_scaler(dataframe, features_to_scale, df_to_concat, saving_path=False):
    try:
        import pandas as pd
        from sklearn.preprocessing import StandardScaler
        from joblib import dump

        #husillo m22
        standard_scaler = StandardScaler()
        standard_scaler.fit(dataframe[features_to_scale].values)
        scaled_dataframe_values = standard_scaler.transform(dataframe[features_to_scale].values)
        scaled_dataframe = pd.DataFrame(columns=features_to_scale, data=scaled_dataframe_values, index = dataframe.index)
        
        features_no_to_scale = [x for x in dataframe.columns if x not in features_to_scale]
        
        assert dataframe.index.all() == scaled_dataframe.index.all()
        
        final_scaled_df = pd.concat([df_to_concat, scaled_dataframe], axis=1) 
        
        if saving_path:
            dump(standard_scaler, saving_path) 

        return final_scaled_df

    except Exception as exc:
        print(exc)
        #return exc

numeric_features = [x for x in tablon_final.columns if x not in ['TARGET', 'DAYS_TILL_SLAG', 'HOUR', 'DAY', 'MONTH']]
dataset_to_concat = tablon_final[['TARGET', 'DAYS_TILL_SLAG', 'HOUR', 'DAY', 'MONTH']]
X_scaled_interpolated = scale_and_save_scaler(X_interpolated, features_to_scale = numeric_features, df_to_concat = dataset_to_concat)

# %%
X_scaled_interpolated.tail()
# Out:
#              TARGET  DAYS_TILL_SLAG  HOUR  DAY  MONTH  Active Power_median  \
# ID_sampling
# 12-31-19          0               0    19   31     12            -2.699895
# 12-31-20          0               0    20   31     12            -2.709318
# 12-31-21          0               0    21   31     12            -2.708999
# 12-31-22          0               0    22   31     12            -2.710773
# 12-31-23          0               0    23   31     12            -1.260923
#
#              Active Power_mean  Active Power_max  Active Power_min  \
# ID_sampling
# 12-31-19             -2.710722         -2.830760         -2.570387
# 12-31-20             -2.705418         -2.747917         -2.592037
# 12-31-21             -2.726121         -2.841609         -2.617003
# 12-31-22             -2.722842         -2.807134         -2.620606
# 12-31-23             -1.506261         -0.895884         -2.598325
#
#              Active Power_std  ...  Air Heater #1 Differential Pressure_max  \
# ID_sampling                    ...
# 12-31-19            -0.330922  ...                                -1.705630
# 12-31-20             0.064814  ...                                -1.435083
# 12-31-21            -0.226161  ...                                -1.711228
# 12-31-22            -0.171512  ...                                -1.698167
# 12-31-23             6.760938  ...                                -0.274528
#
#              Air Heater #1 Differential Pressure_min  \
# ID_sampling
# 12-31-19                                   -1.507947
# 12-31-20                                   -1.533333
# 12-31-21                                   -1.533333
# 12-31-22                                   -1.821644
# 12-31-23                                   -1.625810
#
#              Air Heater #1 Differential Pressure_std  \
# ID_sampling
# 12-31-19                                   -0.448039
# 12-31-20                                    0.328350
# 12-31-21                                   -0.407997
# 12-31-22                                    0.677424
# 12-31-23                                    4.374496
#
#              Air Heater #1 Differential Pressure_skew  \
# ID_sampling
# 12-31-19                                     0.714910
# 12-31-20                                     3.819047
# 12-31-21                                    -1.798494
# 12-31-22                                    -2.444675
# 12-31-23                                    -0.105426
#
#              Reheated Steam Temperature 1 @Outlet_median  \
# ID_sampling
# 12-31-19                                       -0.340337
# 12-31-20                                       -0.331949
# 12-31-21                                       -0.342057
# 12-31-22                                       -0.342057
# 12-31-23                                       -0.206119
#
#              Reheated Steam Temperature 1 @Outlet_mean  \
# ID_sampling
# 12-31-19                                     -0.345679
# 12-31-20                                     -0.326868
# 12-31-21                                     -0.341978
# 12-31-22                                     -0.340005
# 12-31-23                                     -0.135903
#
#              Reheated Steam Temperature 1 @Outlet_max  \
# ID_sampling
# 12-31-19                                    -0.357456
# 12-31-20                                    -0.333481
# 12-31-21                                    -0.370485
# 12-31-22                                    -0.358544
# 12-31-23                                     0.106124
#
#              Reheated Steam Temperature 1 @Outlet_min  \
# ID_sampling
# 12-31-19                                    -0.333201
# 12-31-20                                    -0.313031
# 12-31-21                                    -0.313031
# 12-31-22                                    -0.313031
# 12-31-23                                    -0.324149
#
#              Reheated Steam Temperature 1 @Outlet_std  \
# ID_sampling
# 12-31-19                                    -0.171806
# 12-31-20                                    -0.191312
# 12-31-21                                    -0.539043
# 12-31-22                                    -0.398123
# 12-31-23                                     5.654344
#
#              Reheated Steam Temperature 1 @Outlet_skew
# ID_sampling
# 12-31-19                                     -0.242713
# 12-31-20                                      1.236952
# 12-31-21                                      0.019109
# 12-31-22                                      2.062358
# 12-31-23                                      0.451118
#
# [5 rows x 149 columns]

# %% [markdown]
# ### Guardamos X_scaled_interpolated

# %%
X_scaled_interpolated.to_csv('../data/boiler_Y_train_data_scaled_interpolated.csv')

# %%
X_scaled_interpolated_from_csv = pd.read_csv('../data/boiler_Y_train_data_scaled_interpolated.csv')

# %%
X_scaled_interpolated_from_csv.set_index('ID_sampling', inplace=True)

# %%
X_scaled_interpolated_from_csv
# Out:
#              TARGET  DAYS_TILL_SLAG  HOUR  DAY  MONTH  Active Power_median  \
# ID_sampling
# 01-01-00          0               0     0    1      1             0.315556
# 01-01-01          0               0     1    1      1             0.318278
# 01-01-02          0               0     2    1      1             0.317615
# 01-01-03          0               0     3    1      1             0.315965
# 01-01-04          0               0     4    1      1             0.329135
# ...             ...             ...   ...  ...    ...                  ...
# 12-31-19          0               0    19   31     12            -2.699895
# 12-31-20          0               0    20   31     12            -2.709318
# 12-31-21          0               0    21   31     12            -2.708999
# 12-31-22          0               0    22   31     12            -2.710773
# 12-31-23          0               0    23   31     12            -1.260923
#
#              Active Power_mean  Active Power_max  Active Power_min  \
# ID_sampling
# 01-01-00              0.319098          0.305600          0.342672
# 01-01-01              0.319591          0.306575          0.336465
# 01-01-02              0.319754          0.286789          0.344149
# 01-01-03              0.318521          0.292057          0.332920
# 01-01-04              0.321204          0.372476          0.277699
# ...                        ...               ...               ...
# 12-31-19             -2.710722         -2.830760         -2.570387
# 12-31-20             -2.705418         -2.747917         -2.592037
# 12-31-21             -2.726121         -2.841609         -2.617003
# 12-31-22             -2.722842         -2.807134         -2.620606
# 12-31-23             -1.506261         -0.895884         -2.598325
#
#              Active Power_std  ...  Air Heater #1 Differential Pressure_max  \
# ID_sampling                    ...
# 01-01-00            -0.223289  ...                                -0.115931
# 01-01-01            -0.202701  ...                                -0.108469
# 01-01-02            -0.267642  ...                                -0.121528
# 01-01-03            -0.204081  ...                                -0.115931
# 01-01-04             0.113230  ...                                -0.033835
# ...                       ...  ...                                      ...
# 12-31-19            -0.330922  ...                                -1.705630
# 12-31-20             0.064814  ...                                -1.435083
# 12-31-21            -0.226161  ...                                -1.711228
# 12-31-22            -0.171512  ...                                -1.698167
# 12-31-23             6.760938  ...                                -0.274528
#
#              Air Heater #1 Differential Pressure_min  \
# ID_sampling
# 01-01-00                                   -0.046446
# 01-01-01                                   -0.033755
# 01-01-02                                   -0.021060
# 01-01-03                                   -0.064581
# 01-01-04                                   -0.104470
# ...                                              ...
# 12-31-19                                   -1.507947
# 12-31-20                                   -1.533333
# 12-31-21                                   -1.533333
# 12-31-22                                   -1.821644
# 12-31-23                                   -1.625810
#
#              Air Heater #1 Differential Pressure_std  \
# ID_sampling
# 01-01-00                                   -0.279965
# 01-01-01                                   -0.241505
# 01-01-02                                   -0.310082
# 01-01-03                                   -0.157281
# 01-01-04                                    0.084728
# ...                                              ...
# 12-31-19                                   -0.448039
# 12-31-20                                    0.328350
# 12-31-21                                   -0.407997
# 12-31-22                                    0.677424
# 12-31-23                                    4.374496
#
#              Air Heater #1 Differential Pressure_skew  \
# ID_sampling
# 01-01-00                                     0.544224
# 01-01-01                                    -0.413258
# 01-01-02                                     0.937290
# 01-01-03                                    -1.464765
# 01-01-04                                    -0.098153
# ...                                               ...
# 12-31-19                                     0.714910
# 12-31-20                                     3.819047
# 12-31-21                                    -1.798494
# 12-31-22                                    -2.444675
# 12-31-23                                    -0.105426
#
#              Reheated Steam Temperature 1 @Outlet_median  \
# ID_sampling
# 01-01-00                                        0.214093
# 01-01-01                                        0.257228
# 01-01-02                                        0.256104
# 01-01-03                                        0.216385
# 01-01-04                                        0.182917
# ...                                                  ...
# 12-31-19                                       -0.340337
# 12-31-20                                       -0.331949
# 12-31-21                                       -0.342057
# 12-31-22                                       -0.342057
# 12-31-23                                       -0.206119
#
#              Reheated Steam Temperature 1 @Outlet_mean  \
# ID_sampling
# 01-01-00                                      0.219890
# 01-01-01                                      0.257395
# 01-01-02                                      0.252800
# 01-01-03                                      0.209147
# 01-01-04                                      0.155309
# ...                                                ...
# 12-31-19                                     -0.345679
# 12-31-20                                     -0.326868
# 12-31-21                                     -0.341978
# 12-31-22                                     -0.340005
# 12-31-23                                     -0.135903
#
#              Reheated Steam Temperature 1 @Outlet_max  \
# ID_sampling
# 01-01-00                                     0.208735
# 01-01-01                                     0.244705
# 01-01-02                                     0.233342
# 01-01-03                                     0.206487
# 01-01-04                                     0.182932
# ...                                               ...
# 12-31-19                                    -0.357456
# 12-31-20                                    -0.333481
# 12-31-21                                    -0.370485
# 12-31-22                                    -0.358544
# 12-31-23                                     0.106124
#
#              Reheated Steam Temperature 1 @Outlet_min  \
# ID_sampling
# 01-01-00                                     0.226438
# 01-01-01                                     0.269316
# 01-01-02                                     0.268102
# 01-01-03                                     0.211628
# 01-01-04                                     0.089825
# ...                                               ...
# 12-31-19                                    -0.333201
# 12-31-20                                    -0.313031
# 12-31-21                                    -0.313031
# 12-31-22                                    -0.313031
# 12-31-23                                    -0.324149
#
#              Reheated Steam Temperature 1 @Outlet_std  \
# ID_sampling
# 01-01-00                                    -0.182410
# 01-01-01                                    -0.394893
# 01-01-02                                    -0.368736
# 01-01-03                                    -0.002055
# 01-01-04                                     1.060142
# ...                                               ...
# 12-31-19                                    -0.171806
# 12-31-20                                    -0.191312
# 12-31-21                                    -0.539043
# 12-31-22                                    -0.398123
# 12-31-23                                     5.654344
#
#              Reheated Steam Temperature 1 @Outlet_skew
# ID_sampling
# 01-01-00                                     -0.106896
# 01-01-01                                     -0.386300
# 01-01-02                                     -0.804519
# 01-01-03                                     -0.171798
# 01-01-04                                     -0.943097
# ...                                                ...
# 12-31-19                                     -0.242713
# 12-31-20                                      1.236952
# 12-31-21                                      0.019109
# 12-31-22                                      2.062358
# 12-31-23                                      0.451118
#
# [8759 rows x 149 columns]

# %% [markdown]
# ## Aquí aún no metemos atributos de tiempo (por posible estacionalidad)
# ### Mantenemos 'DAYS_TILL_SLAG' para usarlo en la validación

# %%
X_scaled_interpolated = X_scaled_interpolated_from_csv

numeric_features = [x for x in X_scaled_interpolated.columns if x not in ['TARGET', 'DAYS_TILL_SLAG', 'HOUR', 'DAY', 'MONTH']]

# %%
### Stratified train-test split
from sklearn.model_selection import train_test_split

features_to_train_no_temp = [x for x in X_scaled_interpolated.columns if x not in ['TARGET', 'HOUR', 'DAY', 'MONTH']]
X_train, X_test, y_train, y_test=train_test_split(X_scaled_interpolated[features_to_train_no_temp], 
                                                  X_scaled_interpolated['TARGET'], test_size=0.20, stratify=X_scaled_interpolated['TARGET'])

# %%
from xgboost import plot_importance
from matplotlib import pyplot

from matplotlib.pyplot import figure
figure(figsize=(30, 10))

# split data into X and y
X = X_scaled_interpolated[numeric_features]
y = X_scaled_interpolated['TARGET']
# fit model no training data
model = XGBClassifier(**params)
model.fit(X, y)
# plot feature importance
plot_importance(model)
pyplot.show()

# %%
#CHECK: proporción de positivos en todo el set de datos = proporción en los datos de test
assert round((len(y_test[y_test==1])/len(y_test)), 2) == round((len(X_scaled_interpolated[X_scaled_interpolated['TARGET']==1])/len(X_scaled_interpolated['TARGET'])), 2)

# %% [markdown]
# ### Esto nos hace ver la importancia de probar otro sampleo con el que tengamos más datos, a parte de probar el SMOTE para oversamplear; de hecho necesito los days until slag para la función de coste de EDP, y no puedo oversamplear (no puede generar ficticos days till slag, a priori) <font color='red'> Probar también con el parámetro 'scale_pos_weight' de XGBOOST para el desbalanceo </font>

# %%
X_train_attributes = numeric_features 
X_test_attributes = numeric_features 

train_slagdays_to_concat = X_train['DAYS_TILL_SLAG']
test_slagdays_to_concat = X_test['DAYS_TILL_SLAG']

# %% [markdown]
# ### EDP cost function to evaluate our training

# %%
global defined_model
global features_to_train_on
global n_folds

features_to_train_on = numeric_features
n_folds = 5
from xgboost import XGBClassifier
defined_model = XGBClassifier(objective="binary:logistic", random_state=42)

# %%
### EDP cost function version 1 (falta incluir el coste por FP fuera de warning window):
def return_true_positive_savings(days_until_slag_value, no_return_days=6, tp_repair_cost=350000):
    try:
        tp_savings = tp_repair_cost - ((30-days_until_slag_value)*(tp_repair_cost/(30-no_return_days)))
        
        return tp_savings

    except Exception as exc:
        return exc

 
def return_edp_cost_function(y_preds, y_true_values): 
    """
        True positives (TP) are slagging events that happened in one of the boilers, detected in the warning window 
        (6/12 to 30 days before the date that marks the event). The point of no-return depends on the intensity of the 
        slagging event: 12 days prior to high-intensity slagging events or 6 days prior to low-intensity slagging events. 
        If a slagging event is detected in the warning window but in the wrong boiler, it counts as a false positive. 
        True Positives are translated into savings, according to the following expression:

        False negatives (FN) are real slagging events that happened in one of the boilers that are not detected in the 
        warning window. False negatives are translated into repair and downtime costs.

        False positives (FP) are detections in a boiler where there is no slagging events in the next 30 days. False positives 
        are translated into unnecessary inspection costs.

        Check for the special cases
    """
    
    try:

        costs_dict = {'fp_cost': 19253, 'fn_cost': 350000}

        #true_predicted_tuples = pd.DataFrame({'y_true': y_true_values, 'y_predicted': y_predicted_values, 'days_till_slag': days_until_slag})
        
        #y_predicted_values = defined_model.predict(X_values)
        y_predicted_values = y_preds
        
        true_predicted_tuples = pd.DataFrame({'y_true': y_true_values, 'y_predicted': y_predicted_values, \
                                              'days_till_slag': days_until_slag})
        true_predicted_tuples = true_predicted_tuples.reset_index(drop=True)
        #true positives, false positives and false negatives number
        tp_savings = 0
        
        first_tp_detected = False

        while first_tp_detected==False:
            for index in true_predicted_tuples.index:
                # TRUE POSITIVE condition:
                if ((true_predicted_tuples.iloc[index]['y_true']==1)&(true_predicted_tuples.iloc[index]['y_predicted']==1)):
                    tp_savings += return_true_positive_savings(true_predicted_tuples.iloc[index]['days_till_slag'])
                break
            first_tp_detected = True
        
        fp_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==0)&(true_predicted_tuples.y_predicted==1)])
        fn_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==1)&(true_predicted_tuples.y_predicted==0)])

        final_cost =  ((costs_dict['fp_cost'])*fp_number) + ((costs_dict['fn_cost'])*fn_number) - tp_savings

        return final_cost

    except Exception as exc:
        return exc

# %% [markdown]
# ### Test de la 'return_edp_cost_function'
# #### Coste esperado: asociado a falso positivo = 19253

# %%
y_poc_test_preds = [1]
y_poc_test_true_values = [0]
days_until_slag = [40]

assert return_edp_cost_function(y_poc_test_preds, y_poc_test_true_values) == 19253
print('PASSED')
# Out:
# PASSED

# %%
y_poc_test_preds = [1, 0]
y_poc_test_true_values = [0, 1]
days_until_slag = [40, 30]

assert return_edp_cost_function(y_poc_test_preds, y_poc_test_true_values) == 19253 + 350000
print('PASSED')
# Out:
# PASSED

# %%
tp_savings = 350000 - ((30-9)*(350000/(30-9)))
print('coste a obtener: ', 19253 + 350000 - tp_savings)

print('coste devuelto por return_edp_cost_function: ', return_edp_cost_function(y_poc_test_preds, y_poc_test_true_values))
# Out:
# coste a obtener:  369253.0
# coste devuelto por return_edp_cost_function:  369253

# %% [markdown]
# ### FIN DE TEST DE EDP COST FUNCTION

# %% [markdown]
# ### Plot confusion matrix, fuente: http://rasbt.github.io/mlxtend/user_guide/plotting/plot_confusion_matrix/

# %% [markdown]
# ### Probamos a ajustar las predicciones según diferentes thresolds para cada clase

# %% [markdown]
# #### <font color='green'> Para binario, la idea es: <p>
#     - que reduzcamos el número de falsos positivos estableciendo un threshold de decisión más alto para los días más alejados del slag (entre 31 y 15?)
#     - que reduzcamos falsos negativos, relajando el threshold de decisión a días próximos al slag (< 15?)
#      </font>
#
# #### <font color='green'> Para multiclase, la idea es que reduzcamos el número de falsos negativos, por lo que hacemos que el threshold de decisión para la clase mayoritario ' no slag' sea más exigente, no sólo el máximo </font>

# %%
def assign_prediction_to_binary_probas(clf_prediction_proba, days_till_slag, proba_threshold=0.7, days_till_slag_threshold=15):
    import numpy as np
    import pandas as pd
    
    if days_till_slag > days_till_slag_threshold:
        if clf_prediction_proba[1] > proba_threshold:
            return 1
        else: return 0
    else:
        return np.max(0.5, clf_prediction_proba[1])
    

def assign_prediction_to_multiclass_probas(clf_prediction_probas):
    import numpy as np
    import pandas as pd
    
    preds_df = pd.DataFrame({'preds_probas': clf_prediction_probas, 'class': list(range(0, len(clf_prediction_probas)))})
    if preds_df['preds_probas'][0] < 0.6:
        selected_proba = np.max(clf_prediction_probas[1:])
        final_prediction = preds_df[preds_df['preds_probas']==selected_proba]['class']
    else:
        final_prediction = preds_df[preds_df['preds_probas']==np.max(clf_prediction_probas)]['class']
    
    return final_prediction.values[0]

# %% [markdown]
# ### Hemos definido nuestra función ahorro como la inversa del coste asociado a los errores de nuestras predicciones

# %%
def eval_metric_function_for_training_xgboost(y_preds, y_true_values): 
    try:
        costs_dict = {'fp_cost': 19253, 'fn_cost': 350000}

        y_predicted_values = y_preds

        true_predicted_tuples = pd.DataFrame({'y_true': y_true_values, 'y_predicted': y_predicted_values, \
                                              'days_till_slag': days_until_slag})
        

        true_predicted_tuples = true_predicted_tuples.reset_index(drop=True)
        #true positives, false positives and false negatives number
        tp_savings = 0
        
        first_tp_detected = False

        while first_tp_detected==False:
            for index in true_predicted_tuples.index:
                # TRUE POSITIVE condition:
                if ((true_predicted_tuples.iloc[index]['y_true']==1)&(true_predicted_tuples.iloc[index]['y_predicted']==1)):
                    tp_savings += return_true_positive_savings(true_predicted_tuples.iloc[index]['days_till_slag'])

                    print('tp_savings added: ', tp_savings)
                    
                break
            first_tp_detected = True
        
        fp_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==0)&(true_predicted_tuples.y_predicted==1)])
        fn_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==1)&(true_predicted_tuples.y_predicted==0)])

        final_edp_cost =  ((costs_dict['fp_cost'])*fp_number) + ((costs_dict['fn_cost'])*fn_number) - tp_savings

        return 'eval_metric_function_for_training_xgboost', final_edp_cost

    except Exception as exc:
        raise exc

# %%
def evaluate_model_with_slag_days(dataX, dataY):
    from tqdm import tqdm
    from sklearn.model_selection import KFold
    
    scores, histories = list(), list()
    # prepare cross validation
    kfold = KFold(n_folds, shuffle=True, random_state=1)
    # enumerate splits
    k = 0
    for train_ix, test_ix in tqdm(kfold.split(dataX)):
        print('kfold {}'.format(k))
        
        # select rows for train and test
        trainX, trainY, testX, testY = dataX.iloc[train_ix], dataY.iloc[train_ix], dataX.iloc[test_ix], \
                                       dataY.iloc[test_ix]
        
        global days_until_slag
        days_until_slag = testX['DAYS_TILL_SLAG'] 
        
        # fit model
        history = defined_model.fit(trainX[features_to_train_on], trainY, #early_stopping_rounds=10, 
                                    eval_metric=eval_metric_function_for_training_xgboost, # 'auc'
                                    eval_set=[(testX[features_to_train_on], testY)])                               
        # evaluate model
        y_preds = defined_model.predict(testX[features_to_train_on])
        
        #score = return_edp_cost_function(y_preds, testY) 
        ###########################################################
        costs_dict = {'fp_cost': 19253, 'fn_cost': 350000}
        
        y_true_values = testY
        true_predicted_tuples = pd.DataFrame({'y_true': y_true_values, 'y_predicted': y_preds, \
                                              'days_till_slag': days_until_slag})
        true_predicted_tuples = true_predicted_tuples.reset_index(drop=True)
        #true positives, false positives and false negatives number
        tp_savings = 0
        
        first_tp_detected = False

        while first_tp_detected==False:
            for index in true_predicted_tuples.index:
                # TRUE POSITIVE condition:
                if ((true_predicted_tuples.iloc[index]['y_true']==1)&(true_predicted_tuples.iloc[index]['y_predicted']==1)):
                    tp_savings += return_true_positive_savings(true_predicted_tuples.iloc[index]['days_till_slag'])
                break
            first_tp_detected = True
        
        fp_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==0)&(true_predicted_tuples.y_predicted==1)])
        fn_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==1)&(true_predicted_tuples.y_predicted==0)])

        final_cost =  ((costs_dict['fp_cost'])*fp_number) + ((costs_dict['fn_cost'])*fn_number) - tp_savings
        ##########################################################
        score = final_cost
        
        print('score en evaluate_model_with_slag_days', score)
        
        #print('> %.3f' % (acc * 100.0))
        # append scores
        scores.append(score)
        histories.append(history)
        
        k = k + 1
        
    return defined_model, scores, histories

# %%
### Hiperparam. con Bayesian optimization
from hyperopt import hp
from sklearn.model_selection import StratifiedKFold

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.model_selection import cross_val_score

def return_model_scores(params, dataX, dataY, n_folds=5):
    import numpy as np
    
    defined_model, edp_cost_scores, histories = evaluate_model_with_slag_days(dataX = dataX, dataY = dataY)
    return np.array(edp_cost_scores).mean()


param_space = {'max_depth' : hp.choice('max_depth', range(5, 30, 1)),
    'learning_rate' : hp.quniform('learning_rate', 0.01, 0.5, 0.01),
    'n_estimators' : hp.choice('n_estimators', range(20, 205, 5)),
    'gamma' : hp.quniform('gamma', 0, 0.50, 0.01),
    'min_child_weight' : hp.quniform('min_child_weight', 1, 10, 1),
    'subsample' : hp.quniform('subsample', 0.1, 1, 0.01),
    'colsample_bytree' : hp.quniform('colsample_bytree', 0.1, 1.0, 0.01),
    'scale_pos_weight': hp.uniform('scale_pos_weight', 0.2, 0.8)}

# DEFINO ESTAS VARIABLES GLOBALES AL NO METERLAS COMO PARAMS. DE ENTRADA EN EL BAYESIAN HYPERP.
dataX = X_train
dataY = y_train
assert len(X_train)==len(y_train)
n_folds=5

global best
best = 0
i = 0
def f(params):
    cost = return_model_scores(params, dataX, dataY, n_folds=5)  
    if i == 0:
        best = cost
    
    if cost < best:
        best = cost
        print('new best:', best, params)
    
    return {'loss': cost, 'status': STATUS_OK}

trials = Trials()
best = fmin(f, param_space, algo=tpe.suggest, max_evals=10, trials=trials)

#%%
print ('best:')
print (best)
# Out:
# idation_0-error:0.024268	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:11<00:25, 25.81s/it, best loss: 9250862.6][79]	validation_0-error:0.023555	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:11<00:25, 25.81s/it, best loss: 9250862.6][80]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][81]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][82]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][83]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][84]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][85]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][86]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][87]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][88]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][89]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][90]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][91]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][92]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][93]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][94]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][95]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][96]	validation_0-error:0.022127	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][97]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][98]	validation_0-error:0.022127	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6][99]	validation_0-error:0.021413	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:12<00:25, 25.81s/it, best loss: 9250862.6]score en evaluate_model_with_slag_days
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6]8515518
# 4it [00:20,  5.15s/it]
#
# kfold 4
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][0]	validation_0-error:0.042827	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][1]	validation_0-error:0.042827	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][2]	validation_0-error:0.042827	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][3]	validation_0-error:0.042827	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][4]	validation_0-error:0.042827	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][5]	validation_0-error:0.042827	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][6]	validation_0-error:0.042827	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][7]	validation_0-error:0.037116	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][8]	validation_0-error:0.037116	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][9]	validation_0-error:0.03783	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][10]	validation_0-error:0.03783	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][11]	validation_0-error:0.03783	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][12]	validation_0-error:0.036403	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][13]	validation_0-error:0.03783	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][14]	validation_0-error:0.03783	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][15]	validation_0-error:0.03783	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][16]	validation_0-error:0.036403	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:13<00:25, 25.81s/it, best loss: 9250862.6][17]	validation_0-error:0.036403	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][18]	validation_0-error:0.033547	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][19]	validation_0-error:0.033547	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][20]	validation_0-error:0.034975	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][21]	validation_0-error:0.035689	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][22]	validation_0-error:0.034975	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][23]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][24]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][25]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][26]	validation_0-error:0.035689	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][27]	validation_0-error:0.035689	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][28]	validation_0-error:0.033547	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][29]	validation_0-error:0.034975	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][30]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][31]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][32]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][33]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][34]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][35]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][36]	validation_0-error:0.034261	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:14<00:25, 25.81s/it, best loss: 9250862.6][37]	validation_0-error:0.033547	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][38]	validation_0-error:0.033547	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][39]	validation_0-error:0.033547	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][40]	validation_0-error:0.033547	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][41]	validation_0-error:0.03212	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][42]	validation_0-error:0.03212	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][43]	validation_0-error:0.03212	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][44]	validation_0-error:0.031406	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][45]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][46]	validation_0-error:0.031406	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][47]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][48]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][49]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][50]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][51]	validation_0-error:0.029265	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][52]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][53]	validation_0-error:0.029979	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][54]	validation_0-error:0.029979	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][55]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:15<00:25, 25.81s/it, best loss: 9250862.6][56]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][57]	validation_0-error:0.030692	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][58]	validation_0-error:0.029265	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][59]	validation_0-error:0.028551	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][60]	validation_0-error:0.028551	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][61]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][62]	validation_0-error:0.027123	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][63]	validation_0-error:0.027123	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][64]	validation_0-error:0.028551	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][65]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][66]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][67]	validation_0-error:0.027123	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][68]	validation_0-error:0.027123	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][69]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][70]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][71]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][72]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][73]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][74]	validation_0-error:0.02641	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][75]	validation_0-error:0.02641	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:16<00:25, 25.81s/it, best loss: 9250862.6][76]	validation_0-error:0.027123	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][77]	validation_0-error:0.025696	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][78]	validation_0-error:0.027837	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][79]	validation_0-error:0.027123	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][80]	validation_0-error:0.025696	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][81]	validation_0-error:0.024982	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][82]	validation_0-error:0.024982	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][83]	validation_0-error:0.024982	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][84]	validation_0-error:0.024982	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][85]	validation_0-error:0.02641	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][86]	validation_0-error:0.024982	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][87]	validation_0-error:0.024268	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][88]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][89]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][90]	validation_0-error:0.022127	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][91]	validation_0-error:0.022127	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][92]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][93]	validation_0-error:0.022841	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][94]	validation_0-error:0.022127	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][95]	validation_0-error:0.021413	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][96]	validation_0-error:0.0207	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:17<00:25, 25.81s/it, best loss: 9250862.6][97]	validation_0-error:0.0207	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:18<00:25, 25.81s/it, best loss: 9250862.6][98]	validation_0-error:0.0207	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:18<00:25, 25.81s/it, best loss: 9250862.6][99]	validation_0-error:0.0207	validation_0-eval_metric_function_for_training_xgboost:0
#
#  90%|█████████ | 9/10 [04:18<00:25, 25.81s/it, best loss: 9250862.6]score en evaluate_model_with_slag_days
#  90%|█████████ | 9/10 [04:18<00:25, 25.81s/it, best loss: 9250862.6]8827012
# 5it [00:25,  5.15s/it]
#
# 5it [00:25,  5.15s/it]
# 100%|██████████| 10/10 [04:18<00:00, 25.82s/it, best loss: 9250862.6]
# best:
# {'colsample_bytree': 0.54, 'gamma': 0.24, 'learning_rate': 0.45, 'max_depth': 21, 'min_child_weight': 5.0, 'n_estimators': 33, 'scale_pos_weight': 0.43355351047591884, 'subsample': 0.31}

# %%
best['objective'] = 'binary:logistic'
params= best
xgb = XGBClassifier(**params) #'multi:softprob')

X_test_attributes = [x for x in X_test.columns if x not in ['DAYS_TILL_SLAG']]

eval_set = [(X_test[X_test_attributes], y_test)]
global days_until_slag
days_until_slag = X_test['DAYS_TILL_SLAG']

#selected_attributes = selected_attrs
xgb_best_params = xgb.fit(X_train[X_test_attributes], y_train, eval_metric=eval_metric_function_for_training_xgboost, eval_set=eval_set, verbose=True)        
#xgb_best_params = xgb.fit(X_train[selected_attributes], y_train, eval_metric=eval_metric_function_for_training_xgboost, eval_set=eval_set, verbose=True)

best_params_xgb_predictions = xgb_best_params.predict(X_test[X_test_attributes])
print('with eval_metric = {}'.format('return_edp_savings_function'))
confusion_matrix(y_test, best_params_xgb_predictions)
# Out:
# [0]	validation_0-error:0.057648	validation_0-eval_metric_function_for_training_xgboost:0
# [1]	validation_0-error:0.057648	validation_0-eval_metric_function_for_training_xgboost:0
# [2]	validation_0-error:0.057648	validation_0-eval_metric_function_for_training_xgboost:0
# [3]	validation_0-error:0.033676	validation_0-eval_metric_function_for_training_xgboost:0
# [4]	validation_0-error:0.035388	validation_0-eval_metric_function_for_training_xgboost:0
# [5]	validation_0-error:0.032534	validation_0-eval_metric_function_for_training_xgboost:0
# [6]	validation_0-error:0.032534	validation_0-eval_metric_function_for_training_xgboost:0
# [7]	validation_0-error:0.031393	validation_0-eval_metric_function_for_training_xgboost:0
# [8]	validation_0-error:0.02911	validation_0-eval_metric_function_for_training_xgboost:0
# [9]	validation_0-error:0.030251	validation_0-eval_metric_function_for_training_xgboost:0
# [10]	validation_0-error:0.02911	validation_0-eval_metric_function_for_training_xgboost:0
# [11]	validation_0-error:0.027968	validation_0-eval_metric_function_for_training_xgboost:0
# [12]	validation_0-error:0.026256	validation_0-eval_metric_function_for_training_xgboost:0
# [13]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# [14]	validation_0-error:0.027397	validation_0-eval_metric_function_for_training_xgboost:0
# [15]	validation_0-error:0.025114	validation_0-eval_metric_function_for_training_xgboost:0
# [16]	validation_0-error:0.021689	validation_0-eval_metric_function_for_training_xgboost:0
# [17]	validation_0-error:0.023973	validation_0-eval_metric_function_for_training_xgboost:0
# [18]	validation_0-error:0.023402	validation_0-eval_metric_function_for_training_xgboost:0
# [19]	validation_0-error:0.019977	validation_0-eval_metric_function_for_training_xgboost:0
# [20]	validation_0-error:0.022831	validation_0-eval_metric_function_for_training_xgboost:0
# [21]	validation_0-error:0.022831	validation_0-eval_metric_function_for_training_xgboost:0
# [22]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# [23]	validation_0-error:0.020548	validation_0-eval_metric_function_for_training_xgboost:0
# [24]	validation_0-error:0.020548	validation_0-eval_metric_function_for_training_xgboost:0
# [25]	validation_0-error:0.021119	validation_0-eval_metric_function_for_training_xgboost:0
# [26]	validation_0-error:0.020548	validation_0-eval_metric_function_for_training_xgboost:0
# [27]	validation_0-error:0.022831	validation_0-eval_metric_function_for_training_xgboost:0
# [28]	validation_0-error:0.022831	validation_0-eval_metric_function_for_training_xgboost:0
# [29]	validation_0-error:0.024543	validation_0-eval_metric_function_for_training_xgboost:0
# [30]	validation_0-error:0.025685	validation_0-eval_metric_function_for_training_xgboost:0
# [31]	validation_0-error:0.025114	validation_0-eval_metric_function_for_training_xgboost:0
# [32]	validation_0-error:0.024543	validation_0-eval_metric_function_for_training_xgboost:0
# with eval_metric = return_edp_savings_function
# array([[1648,    3],
#        [  40,   61]], dtype=int64)

# %% [markdown]
# ## Model feature importances

# %%
f = 'gain'
feature_importances = xgb_best_params.get_booster().get_score(importance_type= f)

feature_importances
# Out:
# {'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_mean': 7.3618539525,
#  'Main Steam Turbine Control Valve #B_max': 5.982777598,
#  'Secondary Air Row #5 (Side 2)_min': 5.21072328,
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_median': 5.7554569073333335,
#  'Coal Feeder #1_mean': 6.90781784,
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_median': 7.878308295,
#  'Active Power_median': 2.3815271036666665,
#  'Boiler Outlet Pressure_max': 4.12917972,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #3_median': 2.3863817066666666,
#  'Boiler Furnace Pressure_std': 2.482228436666667,
#  'Boiler Furnace Pressure_mean': 4.488096475,
#  'Secondary Air Row #3 (Side 2)_median': 3.43906355,
#  'Main Steam Turbine Control Valve #D_max': 4.516999563333333,
#  'Main Steam Turbine Control Valve #B_skew': 0.247436523,
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_mean': 5.0980778933333335,
#  'Secondary Air Row #3 (Side 2)_max': 2.758950393333333,
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_min': 4.506832123333333,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #3_mean': 1.89883113,
#  'Coal Feeder #1_min': 17.4726448,
#  'Secondary Air Fan #1 Temperature 2_min': 8.8665896,
#  'Air Heater #1 Differential Pressure_mean': 6.851722715,
#  'Boiler Outlet Pressure_median': 7.0391650199999996,
#  'Coal Feeder #1_max': 4.60749793,
#  'Boosted Overfire Air (Side 1)_max': 6.960177007499999,
#  'Secondary Air Row #5 (Side 2)_std': 2.3557353,
#  'Main Steam Turbine Control Valve #B_median': 4.66950345025,
#  'Coal Feeder #5_mean': 3.80552673,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #1_min': 5.71082306,
#  'Coal Feeder #5_min': 3.3425575899999997,
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_max': 4.585100649999999,
#  'Boiler Feedwater Pressure_max': 7.1644783,
#  'Secondary Air Fan #1 Temperature 2_std': 2.05794477,
#  'Boiler Outlet Pressure_min': 3.108326433333333,
#  'Boosted Overfire Air (Side 1)_min': 7.13581228,
#  'Air Heater #1 Differential Pressure_min': 3.4101753225,
#  'Secondary Air Fan #1 Temperature 2_mean': 8.35124016,
#  'Coal Feeder #1_median': 5.65260315,
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_max': 8.93370819,
#  'Boiler Feedwater Pressure_median': 5.22210836,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #2_min': 5.52341056,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #2_max': 1.29857063,
#  'Boiler Outlet Pressure_skew': 1.05137014,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #3_min': 5.75047016,
#  'Total Atemperator Feedwater Flow_max': 4.13528824,
#  'Main Steam First Desuperheater Control Valve position (Side 2)_min': 6.98350525,
#  'Secondary Air Row #3 (Side 2)_skew': 1.09901619,
#  'Boiler Outlet Pressure_mean': 6.10137653,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #1_max': 3.086510775,
#  'Main Steam Second Desuperheater Control Valve position (Side 1)_max': 3.8278683449999997,
#  'Coal Feeder #5_median': 1.82025099,
#  'Boiler Furnace Pressure_max': 2.80676627,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #1_std': 1.57674944,
#  'Main Steam First Desuperheater Control Valve position (Side 2)_std': 2.03016257,
#  'Reheated Steam Temperature 1 @Outlet_skew': 1.88479471,
#  'Boiler Feedwater Pressure_std': 4.07723343,
#  'Secondary Air Row #3 (Side 2)_mean': 3.76955128,
#  'Active Power_mean': 5.21495819,
#  'Secondary Air Row #3 (Side 2)_std': 3.3271920699999997,
#  'Boosted Overfire Air (Side 2)_mean': 2.948147415,
#  'Air Heater #1 Differential Pressure_std': 2.72964978,
#  'Air Heater #1 Differential Pressure_skew': 3.36660767,
#  'Secondary Air Row #5 (Side 2)_skew': 2.480572345,
#  'Main Steam First Desuperheater Control Valve position (Side 1)_std': 3.4907710549999997,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #2_std': 2.788110255,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #2_mean': 2.27873516,
#  'Boiler Outlet Pressure_std': 3.990482335,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #3_std': 2.61374402,
#  'Air Heater #1 Differential Pressure_max': 3.3230474,
#  'Reheated Steam Temperature 1 @Outlet_std': 3.13103724,
#  'Main Steam Turbine Control Valve #D_std': 2.5680809,
#  'Secondary Air Row #5 (Side 2)_median': 0.841907382,
#  'Boosted Overfire Air (Side 1)_mean': 12.8904676,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #2_skew': 2.46124244,
#  'Coal Feeder #5_skew': 2.055166485,
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_skew': 2.4772415184999996,
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #1_median': 1.41218472,
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_min': 2.51277637,
#  'Total Atemperator Feedwater Flow_std': 2.88615727,
#  'Boosted Overfire Air (Side 1)_median': 4.13162518,
#  'Main Steam Turbine Control Valve #D_min': 3.14946079,
#  'Main Steam Second Desuperheater Control Valve position (Side 1)_mean': 3.08952808,
#  'Boosted Overfire Air (Side 2)_min': 3.88291359,
#  'Main Steam Second Desuperheater Control Valve position (Side 1)_std': 1.94115627,
#  'Boiler Furnace Pressure_skew': 3.65023994,
#  'Main Steam Turbine Control Valve #D_skew': 2.03048158,
#  'Coal Feeder #5_max': 4.88155651,
#  'Main Steam Turbine Control Valve #B_mean': 0.826366425}

# %%
import seaborn as sns
sns.set(style="whitegrid")

f_importances = [value for key, value in feature_importances.items()]
ax = sns.distplot(f_importances)

# %%
selected_features = [key for key, value in feature_importances.items() if value > 3]
selected_features
# Out:
# ['Flue Gas Induced Draft Fan #1 Blade Pitch Angle_mean',
#  'Main Steam Turbine Control Valve #B_max',
#  'Secondary Air Row #5 (Side 2)_min',
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_median',
#  'Coal Feeder #1_mean',
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_median',
#  'Boiler Outlet Pressure_max',
#  'Boiler Furnace Pressure_mean',
#  'Secondary Air Row #3 (Side 2)_median',
#  'Main Steam Turbine Control Valve #D_max',
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_mean',
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_min',
#  'Coal Feeder #1_min',
#  'Secondary Air Fan #1 Temperature 2_min',
#  'Air Heater #1 Differential Pressure_mean',
#  'Boiler Outlet Pressure_median',
#  'Coal Feeder #1_max',
#  'Boosted Overfire Air (Side 1)_max',
#  'Main Steam Turbine Control Valve #B_median',
#  'Coal Feeder #5_mean',
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #1_min',
#  'Coal Feeder #5_min',
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_max',
#  'Boiler Feedwater Pressure_max',
#  'Boiler Outlet Pressure_min',
#  'Boosted Overfire Air (Side 1)_min',
#  'Air Heater #1 Differential Pressure_min',
#  'Secondary Air Fan #1 Temperature 2_mean',
#  'Coal Feeder #1_median',
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_max',
#  'Boiler Feedwater Pressure_median',
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #2_min',
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #3_min',
#  'Total Atemperator Feedwater Flow_max',
#  'Main Steam First Desuperheater Control Valve position (Side 2)_min',
#  'Boiler Outlet Pressure_mean',
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #1_max',
#  'Main Steam Second Desuperheater Control Valve position (Side 1)_max',
#  'Boiler Feedwater Pressure_std',
#  'Secondary Air Row #3 (Side 2)_mean',
#  'Active Power_mean',
#  'Secondary Air Row #3 (Side 2)_std',
#  'Air Heater #1 Differential Pressure_skew',
#  'Main Steam First Desuperheater Control Valve position (Side 1)_std',
#  'Boiler Outlet Pressure_std',
#  'Air Heater #1 Differential Pressure_max',
#  'Reheated Steam Temperature 1 @Outlet_std',
#  'Boosted Overfire Air (Side 1)_mean',
#  'Boosted Overfire Air (Side 1)_median',
#  'Main Steam Turbine Control Valve #D_min',
#  'Main Steam Second Desuperheater Control Valve position (Side 1)_mean',
#  'Boosted Overfire Air (Side 2)_min',
#  'Boiler Furnace Pressure_skew',
#  'Coal Feeder #5_max']

# %% [markdown]
# ## Retrain con most important features

# %%
best['objective'] = 'binary:logistic'
params= best
xgb = XGBClassifier(**params) 

X_test_attributes = [x for x in X_test.columns if x not in ['DAYS_TILL_SLAG']]

eval_set = [(X_test[selected_features], y_test)]
global days_until_slag
days_until_slag = X_test['DAYS_TILL_SLAG']

xgb_best_params = xgb.fit(X_train[selected_features], y_train, eval_metric=eval_metric_function_for_training_xgboost, eval_set=eval_set, verbose=True)        

best_params_xgb_predictions = xgb_best_params.predict(X_test[selected_features])
print('with eval_metric = {}'.format('return_edp_savings_function'))
confusion_matrix(y_test, best_params_xgb_predictions)
# Out:
# [0]	validation_0-error:0.055936	validation_0-eval_metric_function_for_training_xgboost:0
# [1]	validation_0-error:0.057648	validation_0-eval_metric_function_for_training_xgboost:0
# [2]	validation_0-error:0.057648	validation_0-eval_metric_function_for_training_xgboost:0
# [3]	validation_0-error:0.035959	validation_0-eval_metric_function_for_training_xgboost:0
# [4]	validation_0-error:0.033105	validation_0-eval_metric_function_for_training_xgboost:0
# [5]	validation_0-error:0.038813	validation_0-eval_metric_function_for_training_xgboost:0
# [6]	validation_0-error:0.034247	validation_0-eval_metric_function_for_training_xgboost:0
# [7]	validation_0-error:0.038242	validation_0-eval_metric_function_for_training_xgboost:0
# [8]	validation_0-error:0.032534	validation_0-eval_metric_function_for_training_xgboost:0
# [9]	validation_0-error:0.034247	validation_0-eval_metric_function_for_training_xgboost:0
# [10]	validation_0-error:0.030822	validation_0-eval_metric_function_for_training_xgboost:0
# [11]	validation_0-error:0.031393	validation_0-eval_metric_function_for_training_xgboost:0
# [12]	validation_0-error:0.028539	validation_0-eval_metric_function_for_training_xgboost:0
# [13]	validation_0-error:0.027968	validation_0-eval_metric_function_for_training_xgboost:0
# [14]	validation_0-error:0.026256	validation_0-eval_metric_function_for_training_xgboost:0
# [15]	validation_0-error:0.026256	validation_0-eval_metric_function_for_training_xgboost:0
# [16]	validation_0-error:0.025114	validation_0-eval_metric_function_for_training_xgboost:0
# [17]	validation_0-error:0.026256	validation_0-eval_metric_function_for_training_xgboost:0
# [18]	validation_0-error:0.026256	validation_0-eval_metric_function_for_training_xgboost:0
# [19]	validation_0-error:0.026826	validation_0-eval_metric_function_for_training_xgboost:0
# [20]	validation_0-error:0.025114	validation_0-eval_metric_function_for_training_xgboost:0
# [21]	validation_0-error:0.024543	validation_0-eval_metric_function_for_training_xgboost:0
# [22]	validation_0-error:0.024543	validation_0-eval_metric_function_for_training_xgboost:0
# [23]	validation_0-error:0.024543	validation_0-eval_metric_function_for_training_xgboost:0
# [24]	validation_0-error:0.023973	validation_0-eval_metric_function_for_training_xgboost:0
# [25]	validation_0-error:0.025685	validation_0-eval_metric_function_for_training_xgboost:0
# [26]	validation_0-error:0.023973	validation_0-eval_metric_function_for_training_xgboost:0
# [27]	validation_0-error:0.023402	validation_0-eval_metric_function_for_training_xgboost:0
# [28]	validation_0-error:0.022831	validation_0-eval_metric_function_for_training_xgboost:0
# [29]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# [30]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# [31]	validation_0-error:0.021689	validation_0-eval_metric_function_for_training_xgboost:0
# [32]	validation_0-error:0.021119	validation_0-eval_metric_function_for_training_xgboost:0
# with eval_metric = return_edp_savings_function
# array([[1649,    2],
#        [  35,   66]], dtype=int64)

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, best_params_xgb_predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True)

# %%
global days_until_slag

days_until_slag = X_test['DAYS_TILL_SLAG']

return_edp_cost_function(best_params_xgb_predictions, y_test)
# Out:
# 12288506

# %%
days_until_slag = X_test['DAYS_TILL_SLAG']

return_edp_cost_function(best_params_xgb_predictions, y_test)
# Out:
# 12288506

# %%
best_params_eval_results_df = pd.DataFrame({'y_true_values': y_test, 'y_predicted_values': best_params_xgb_predictions})
best_params_eval_results_df[best_params_eval_results_df.y_predicted_values==1]
# Out:
#              y_true_values  y_predicted_values
# ID_sampling
# 08-27-10                 1                   1
# 08-16-12                 1                   1
# 08-25-14                 1                   1
# 08-19-22                 1                   1
# 08-14-05                 1                   1
# ...                    ...                 ...
# 08-14-11                 1                   1
# 08-12-01                 1                   1
# 08-20-20                 1                   1
# 08-12-20                 1                   1
# 08-20-00                 1                   1
#
# [68 rows x 2 columns]

# %%
best_params_eval_results_df[best_params_eval_results_df.y_predicted_values==1].index
# Out:
# Index(['08-27-10', '08-16-12', '08-25-14', '08-19-22', '08-14-05', '08-26-13',
#        '08-21-09', '08-21-22', '08-15-01', '08-15-10', '08-11-16', '08-23-02',
#        '08-25-15', '08-16-17', '08-15-00', '08-16-22', '08-13-21', '08-23-00',
#        '08-18-01', '08-17-21', '08-11-10', '08-24-10', '08-14-04', '08-10-22',
#        '08-12-14', '08-12-19', '08-12-04', '08-15-13', '08-21-01', '08-11-11',
#        '09-13-08', '08-25-19', '08-13-07', '08-08-15', '08-23-18', '08-13-04',
#        '08-11-04', '08-11-14', '08-21-00', '08-20-21', '08-12-03', '08-22-02',
#        '08-27-05', '08-14-03', '08-23-19', '08-16-20', '08-24-00', '08-21-04',
#        '08-14-15', '08-11-02', '08-13-18', '08-20-22', '08-13-09', '08-11-12',
#        '08-24-08', '08-25-09', '08-12-18', '08-14-21', '08-16-18', '08-20-08',
#        '07-22-15', '08-13-12', '08-28-06', '08-14-11', '08-12-01', '08-20-20',
#        '08-12-20', '08-20-00'],
#       dtype='object', name='ID_sampling')

# %% [markdown]
# # Almacenamos el modelo predictor clasificador

# %%
import pickle

file_data = r'..\models\xgb_best_params_right_boiler_Y_3.pkl'
file_data = open(file_data, 'wb')
pickle.dump(xgb_best_params, file_data)
file_data.close()

# %% [markdown]
# ### Probamos con otro  threshold para las feature importances

# %%
selected_features_thres_4 = [key for key, value in feature_importances.items() if value > 4]
selected_features_thres_4
# Out:
# ['Flue Gas Induced Draft Fan #1 Blade Pitch Angle_mean',
#  'Main Steam Turbine Control Valve #B_max',
#  'Secondary Air Row #5 (Side 2)_min',
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_median',
#  'Coal Feeder #1_mean',
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_median',
#  'Boiler Outlet Pressure_max',
#  'Boiler Furnace Pressure_mean',
#  'Main Steam Turbine Control Valve #D_max',
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_mean',
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_min',
#  'Coal Feeder #1_min',
#  'Secondary Air Fan #1 Temperature 2_min',
#  'Air Heater #1 Differential Pressure_mean',
#  'Boiler Outlet Pressure_median',
#  'Coal Feeder #1_max',
#  'Boosted Overfire Air (Side 1)_max',
#  'Main Steam Turbine Control Valve #B_median',
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #1_min',
#  'Main Steam Second Desuperheater Control Valve position (Side 2)_max',
#  'Boiler Feedwater Pressure_max',
#  'Boosted Overfire Air (Side 1)_min',
#  'Secondary Air Fan #1 Temperature 2_mean',
#  'Coal Feeder #1_median',
#  'Flue Gas Induced Draft Fan #1 Blade Pitch Angle_max',
#  'Boiler Feedwater Pressure_median',
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #2_min',
#  'Dynamic Coal Classifier Rotational Speed Coal Mill #3_min',
#  'Total Atemperator Feedwater Flow_max',
#  'Main Steam First Desuperheater Control Valve position (Side 2)_min',
#  'Boiler Outlet Pressure_mean',
#  'Boiler Feedwater Pressure_std',
#  'Active Power_mean',
#  'Boosted Overfire Air (Side 1)_mean',
#  'Boosted Overfire Air (Side 1)_median',
#  'Coal Feeder #5_max']

# %%
best['objective'] = 'binary:logistic'
params= best
xgb = XGBClassifier(**params) 

X_test_attributes = [x for x in X_test.columns if x not in ['DAYS_TILL_SLAG']]

eval_set = [(X_test[selected_features_thres_4], y_test)]
global days_until_slag
days_until_slag = X_test['DAYS_TILL_SLAG']

xgb_best_params = xgb.fit(X_train[selected_features_thres_4], y_train, eval_metric=eval_metric_function_for_training_xgboost, eval_set=eval_set, verbose=True)        

best_params_xgb_predictions = xgb_best_params.predict(X_test[selected_features_thres_4])
print('with eval_metric = {}'.format('return_edp_savings_function'))
confusion_matrix(y_test, best_params_xgb_predictions)
# Out:
# [0]	validation_0-error:0.054795	validation_0-eval_metric_function_for_training_xgboost:0
# [1]	validation_0-error:0.057078	validation_0-eval_metric_function_for_training_xgboost:0
# [2]	validation_0-error:0.057078	validation_0-eval_metric_function_for_training_xgboost:0
# [3]	validation_0-error:0.042808	validation_0-eval_metric_function_for_training_xgboost:0
# [4]	validation_0-error:0.038813	validation_0-eval_metric_function_for_training_xgboost:0
# [5]	validation_0-error:0.034247	validation_0-eval_metric_function_for_training_xgboost:0
# [6]	validation_0-error:0.033105	validation_0-eval_metric_function_for_training_xgboost:0
# [7]	validation_0-error:0.030822	validation_0-eval_metric_function_for_training_xgboost:0
# [8]	validation_0-error:0.02968	validation_0-eval_metric_function_for_training_xgboost:0
# [9]	validation_0-error:0.02968	validation_0-eval_metric_function_for_training_xgboost:0
# [10]	validation_0-error:0.030822	validation_0-eval_metric_function_for_training_xgboost:0
# [11]	validation_0-error:0.031963	validation_0-eval_metric_function_for_training_xgboost:0
# [12]	validation_0-error:0.027968	validation_0-eval_metric_function_for_training_xgboost:0
# [13]	validation_0-error:0.02911	validation_0-eval_metric_function_for_training_xgboost:0
# [14]	validation_0-error:0.028539	validation_0-eval_metric_function_for_training_xgboost:0
# [15]	validation_0-error:0.027968	validation_0-eval_metric_function_for_training_xgboost:0
# [16]	validation_0-error:0.030822	validation_0-eval_metric_function_for_training_xgboost:0
# [17]	validation_0-error:0.030822	validation_0-eval_metric_function_for_training_xgboost:0
# [18]	validation_0-error:0.02968	validation_0-eval_metric_function_for_training_xgboost:0
# [19]	validation_0-error:0.02968	validation_0-eval_metric_function_for_training_xgboost:0
# [20]	validation_0-error:0.027968	validation_0-eval_metric_function_for_training_xgboost:0
# [21]	validation_0-error:0.025114	validation_0-eval_metric_function_for_training_xgboost:0
# [22]	validation_0-error:0.027397	validation_0-eval_metric_function_for_training_xgboost:0
# [23]	validation_0-error:0.026826	validation_0-eval_metric_function_for_training_xgboost:0
# [24]	validation_0-error:0.027968	validation_0-eval_metric_function_for_training_xgboost:0
# [25]	validation_0-error:0.025685	validation_0-eval_metric_function_for_training_xgboost:0
# [26]	validation_0-error:0.024543	validation_0-eval_metric_function_for_training_xgboost:0
# [27]	validation_0-error:0.022831	validation_0-eval_metric_function_for_training_xgboost:0
# [28]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# [29]	validation_0-error:0.022831	validation_0-eval_metric_function_for_training_xgboost:0
# [30]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# [31]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# [32]	validation_0-error:0.02226	validation_0-eval_metric_function_for_training_xgboost:0
# with eval_metric = return_edp_savings_function
# array([[1645,    6],
#        [  33,   68]], dtype=int64)

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, best_params_xgb_predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True)

# %%
preds_probas_df = pd.DataFrame({'y_true_values': y_test, 'y_predicted_values': best_params_xgb_predictions, 'y_predicted_probas': xgb_best_params.predict_proba(X_test[selected_features_thres_4])[:, 1]})
positive_preds_probas_df = preds_probas_df[preds_probas_df.y_predicted_values==1]
positive_preds_probas_df
# Out:
#              y_true_values  y_predicted_values  y_predicted_probas
# ID_sampling
# 08-27-10                 1                   1            0.537768
# 08-16-12                 1                   1            0.912212
# 08-25-14                 1                   1            0.911124
# 08-19-22                 1                   1            0.978526
# 08-14-05                 1                   1            0.889576
# ...                    ...                 ...                 ...
# 08-12-01                 1                   1            0.593608
# 08-20-20                 1                   1            0.909925
# 08-12-20                 1                   1            0.935455
# 08-20-00                 1                   1            0.908615
# 08-28-08                 1                   1            0.675304
#
# [74 rows x 3 columns]

# %% [markdown]
# ## Plot de la distribución de probabilidades de nuestro clasificador

# %% [markdown]
# ### Este plot corresponde al modelo sin selección de atributos

# %%
import seaborn as sns
sns.set(style="whitegrid")

ax = sns.distplot(positive_preds_probas_df.y_predicted_probas)

# %% [markdown]
# ### Y éste al último de selección de atributos con thres. 0.4

# %%
import seaborn as sns
sns.set(style="whitegrid")

ax = sns.distplot(positive_preds_probas_df.y_predicted_probas)

# %%
from sklearn.metrics import roc_auc_score

print('roc_auc_score con validation set: ', roc_auc_score(preds_probas_df.y_true_values, 
      preds_probas_df.y_predicted_probas))
# Out:
# roc_auc_score con validation set:0.9855593069906626

# %% [markdown]
# ### Almacenamos este último buen modelo

# %%
import pickle

file_data = r'..\models\xgb_best_params_right_boiler_Y_feat_sel_thres_4.pkl'
file_data = open(file_data, 'wb')
pickle.dump(xgb_best_params, file_data)
file_data.close()

# %% [markdown]
# ## La idea es predecir slag en el primer día que encontremos cuyo valor mediano (de entre los 24 registros horarios que tenga) de las probabilidades sea superior a un umbral definido, que según la distribución anterior podríamos situar en 0.8 por ej

# %%
positive_preds_probas_df[positive_preds_probas_df.y_predicted_probas > 0.8]
# Out:
#              y_true_values  y_predicted_values  y_predicted_probas
# ID_sampling
# 08-16-12                 1                   1            0.892792
# 08-19-22                 1                   1            0.813801
# 08-14-05                 1                   1            0.851950
# 08-15-01                 1                   1            0.892792
# 08-15-10                 1                   1            0.894311
# 08-11-16                 1                   1            0.869439
# 08-25-15                 1                   1            0.853799
# 08-16-17                 1                   1            0.925735
# 08-15-00                 1                   1            0.939482
# 08-16-22                 1                   1            0.823749
# 08-13-21                 1                   1            0.892792
# 08-18-01                 1                   1            0.890450
# 08-11-10                 1                   1            0.852390
# 08-14-04                 1                   1            0.921311
# 08-10-22                 1                   1            0.833837
# 08-12-19                 1                   1            0.853868
# 08-15-13                 1                   1            0.916955
# 08-21-01                 1                   1            0.930463
# 08-13-07                 1                   1            0.892792
# 08-08-15                 1                   1            0.806410
# 08-13-04                 1                   1            0.945822
# 08-11-04                 1                   1            0.917013
# 08-11-14                 1                   1            0.818475
# 08-12-03                 1                   1            0.816298
# 08-14-03                 1                   1            0.921311
# 08-16-20                 1                   1            0.867917
# 08-11-02                 1                   1            0.887800
# 08-13-18                 1                   1            0.921311
# 08-20-22                 1                   1            0.810239
# 08-13-09                 1                   1            0.894311
# 08-11-12                 1                   1            0.983883
# 08-12-18                 1                   1            0.870004
# 08-14-21                 1                   1            0.916955
# 08-16-18                 1                   1            0.903859
# 08-20-08                 1                   1            0.918101
# 07-22-15                 0                   1            0.856773
# 08-13-12                 1                   1            0.958587
# 08-28-06                 1                   1            0.888968
# 08-12-01                 1                   1            0.896428
# 08-20-20                 1                   1            0.831117
# 08-20-00                 1                   1            0.818864

# %%
unique_ID_values = positive_preds_probas_df.index
unique_days = [x.split('-')[1] for x in unique_ID_values]
unique_months = [x.split('-')[0] for x in unique_ID_values]

positive_preds_probas_df['month'] = unique_months
positive_preds_probas_df['day'] = unique_days

daily_median_pred_probs = positive_preds_probas_df.groupby(['month', 'day'])['y_predicted_probas'].agg(['median']) #.reset_index(drop=True)
daily_median_pred_probs_df = pd.DataFrame(daily_median_pred_probs)

# %%
daily_median_pred_probs_df.sort_values(by=['month', 'day'], axis='index')
# Out:
#              median
# month day
# 07    22   0.856773
#       31   0.554905
# 08    08   0.806410
#       10   0.780003
#       11   0.869439
#       12   0.804535
#       13   0.907811
#       14   0.851950
#       15   0.905633
#       16   0.892792
#       17   0.775887
#       18   0.890450
#       19   0.813801
#       20   0.818864
#       21   0.779889
#       23   0.744475
#       25   0.681529
#       27   0.579196
#       28   0.733784

# %%
X_test.index
# Out:
# Index(['06-25-05', '09-12-16', '09-02-07', '09-15-13', '05-19-11', '06-28-09',
#        '10-06-15', '01-24-08', '08-02-12', '05-06-13',
#        ...
#        '12-01-05', '01-20-13', '10-12-01', '02-11-14', '02-12-07', '11-02-08',
#        '12-26-16', '05-20-13', '06-20-22', '01-10-01'],
#       dtype='object', name='ID_sampling', length=1752)

# %%
daily_median_pred_probs_df
daily_median_pred_probs_df.index

import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

daily_median_pred_probs_df['string_index'] = [str(x) for x in daily_median_pred_probs_df.index]
ax = sns.lineplot(x='string_index', y="median", data=daily_median_pred_probs_df.sort_values(by=['month', 'day'], axis='index'))

# %% [markdown]
# # Por ahora mapearé probs > 0.65 como días slag

# %% [markdown]
# ## Pruebo un modelo con otros hiperparams aleatorios para validar que los resultados son buenos:

# %%
random_params = {'colsample_bytree': 0.95, 'gamma': 1, 'learning_rate': 0.15, 'max_depth': 2, 'min_child_weight': 3.0, 'n_estimators': 35, 'scale_pos_weight': 0.5539778217188118, 'subsample': 0.79}
random_params['objective'] = 'binary:logistic'
params= best
xgb_random_params = XGBClassifier(**random_params) #'multi:softprob')

X_test_attributes = [x for x in X_test.columns if x not in ['DAYS_TILL_SLAG']]

eval_set = [(X_test[X_test_attributes], y_test)]

xgb_random_params = xgb_random_params.fit(X_train[X_test_attributes], y_train, eval_metric=eval_metric_function_for_training_xgboost, eval_set=eval_set, verbose=True)              #eval_metric_function_for_training_xgboost, #'auc', 
              
xgb_random_params_xgb_predictions = xgb_random_params.predict(X_test[X_test_attributes])
print('with eval_metric = {}'.format('return_edp_savings_function'))
confusion_matrix(y_test, xgb_random_params_xgb_predictions)

# %%
xgb_rand_params_xgb_predictions_eval_results_df = pd.DataFrame({'y_true_values': y_test, 'y_predicted_values': xgb_random_params_xgb_predictions})
xgb_rand_params_xgb_predictions_eval_results_df[xgb_rand_params_xgb_predictions_eval_results_df.y_true_values==1]

# %%
xgb_rand_params_xgb_predictions_eval_results_df[xgb_rand_params_xgb_predictions_eval_results_df.y_predicted_values==1].index

# %%
xgb_best_params_right_boiler_Y

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, xgb_random_params_xgb_predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True)

# %% [markdown]
# ## Confirmo que utilizando los best hiperparams de la hiperparam. bayesiana nos da mejor matriz de confusión (sobre todo, mejor ratio de verdaderos positivos)

# %% [markdown]
# # Repito entrenamientos con eval_metric = 'auc'

# %%
def evaluate_model_with_slag_days_auc(dataX, dataY):
    from tqdm import tqdm
    from sklearn.model_selection import KFold
    
    scores, histories = list(), list()
    # prepare cross validation
    kfold = KFold(n_folds, shuffle=True, random_state=1)
    # enumerate splits
    k = 0
    for train_ix, test_ix in tqdm(kfold.split(dataX)):
        print('kfold {}'.format(k))
        
        # select rows for train and test
        trainX, trainY, testX, testY = dataX.iloc[train_ix], dataY.iloc[train_ix], dataX.iloc[test_ix], \
                                       dataY.iloc[test_ix]
        
        days_until_slag = testX['DAYS_TILL_SLAG'] 
        
        # fit model
        history = defined_model.fit(trainX[features_to_train_on], trainY, #early_stopping_rounds=10, 
                                    eval_metric= 'auc',
                                    eval_set=[(testX[features_to_train_on], testY)])                               
        # evaluate model
        y_preds = defined_model.predict(testX[features_to_train_on])
        
        #score = return_edp_cost_function(y_preds, testY) 
        ###########################################################
        costs_dict = {'fp_cost': 19253, 'fn_cost': 350000}
        
        y_true_values = testY
        true_predicted_tuples = pd.DataFrame({'y_true': y_true_values, 'y_predicted': y_preds, \
                                              'days_till_slag': days_until_slag})
        true_predicted_tuples = true_predicted_tuples.reset_index(drop=True)
        #true positives, false positives and false negatives number
        tp_savings = 0
        
        first_tp_detected = False

        while first_tp_detected==False:
            for index in true_predicted_tuples.index:
                # TRUE POSITIVE condition:
                if ((true_predicted_tuples.iloc[index]['y_true']==1)&(true_predicted_tuples.iloc[index]['y_predicted']==1)):
                    tp_savings += return_true_positive_savings(true_predicted_tuples.iloc[index]['days_till_slag'])
                break
            first_tp_detected = True
        
        fp_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==0)&(true_predicted_tuples.y_predicted==1)])
        fn_number = len(true_predicted_tuples[(true_predicted_tuples.y_true==1)&(true_predicted_tuples.y_predicted==0)])

        final_cost =  ((costs_dict['fp_cost'])*fp_number) + ((costs_dict['fn_cost'])*fn_number) - tp_savings
        ##########################################################
        score = final_cost
        
        print('score en evaluate_model_with_slag_days', score)
        
        #print('> %.3f' % (acc * 100.0))
        # append scores
        scores.append(score)
        histories.append(history)
        
        k = k + 1
        
    return defined_model, scores, histories

# %%
### Hiperparam. con Bayesian optimization
from hyperopt import hp
from sklearn.model_selection import StratifiedKFold

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.model_selection import cross_val_score

def return_model_scores(params, dataX, dataY, n_folds=5):
    import numpy as np
    
    defined_model, edp_cost_scores, histories = evaluate_model_with_slag_days_auc(dataX = dataX, dataY = dataY)   
    print(edp_cost_scores)
    return np.array(edp_cost_scores).mean()


param_space = {'max_depth' : hp.choice('max_depth', range(5, 30, 1)),
    'learning_rate' : hp.quniform('learning_rate', 0.01, 0.5, 0.01),
    'n_estimators' : hp.choice('n_estimators', range(20, 205, 5)),
    'gamma' : hp.quniform('gamma', 0, 0.50, 0.01),
    'min_child_weight' : hp.quniform('min_child_weight', 1, 10, 1),
    'subsample' : hp.quniform('subsample', 0.1, 1, 0.01),
    'colsample_bytree' : hp.quniform('colsample_bytree', 0.1, 1.0, 0.01),
    'scale_pos_weight': hp.uniform('scale_pos_weight', 0.2, 0.8)}

# DEFINO ESTAS VARIABLES GLOBALES AL NO METERLAS COMO PARAMS. DE ENTRADA EN EL BAYESIAN HYPERP.
dataX = X_train
dataY = y_train
assert len(X_train)==len(y_train)
n_folds=5

global best
best = 0
i = 0
def f(params):
    cost = return_model_scores(params, dataX, dataY, n_folds=5)  
    if i == 0:
        best = cost
    
    if cost < best:
        best = cost
        print('new best:', best, params)
    
    return {'loss': cost, 'status': STATUS_OK}

trials = Trials()
best = fmin(f, param_space, algo=tpe.suggest, max_evals=10, trials=trials)

#%%
print ('best:')
print (best)
# Out:
# ███████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][7]	validation_0-auc:0.927689
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][8]	validation_0-auc:0.93317
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][9]	validation_0-auc:0.934649
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][10]	validation_0-auc:0.934845
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][11]	validation_0-auc:0.936
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][12]	validation_0-auc:0.937292
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][13]	validation_0-auc:0.937733
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][14]	validation_0-auc:0.938412
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][15]	validation_0-auc:0.93787
#
#  90%|█████████ | 9/10 [04:20<00:27, 27.02s/it, best loss: 4716954.2][16]	validation_0-auc:0.939978
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][17]	validation_0-auc:0.939751
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][18]	validation_0-auc:0.939751
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][19]	validation_0-auc:0.940267
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][20]	validation_0-auc:0.941676
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][21]	validation_0-auc:0.941953
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][22]	validation_0-auc:0.956033
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][23]	validation_0-auc:0.955897
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][24]	validation_0-auc:0.958286
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][25]	validation_0-auc:0.958465
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][26]	validation_0-auc:0.95875
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][27]	validation_0-auc:0.96073
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][28]	validation_0-auc:0.96105
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][29]	validation_0-auc:0.961346
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][30]	validation_0-auc:0.961869
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][31]	validation_0-auc:0.961565
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][32]	validation_0-auc:0.963216
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][33]	validation_0-auc:0.962912
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][34]	validation_0-auc:0.962966
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][35]	validation_0-auc:0.96436
#
#  90%|█████████ | 9/10 [04:21<00:27, 27.02s/it, best loss: 4716954.2][36]	validation_0-auc:0.96413
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][37]	validation_0-auc:0.96509
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][38]	validation_0-auc:0.964817
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][39]	validation_0-auc:0.967545
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][40]	validation_0-auc:0.967947
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][41]	validation_0-auc:0.971675
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][42]	validation_0-auc:0.970731
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][43]	validation_0-auc:0.97061
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][44]	validation_0-auc:0.971625
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][45]	validation_0-auc:0.972436
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][46]	validation_0-auc:0.971609
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][47]	validation_0-auc:0.97221
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][48]	validation_0-auc:0.9715
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][49]	validation_0-auc:0.973077
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][50]	validation_0-auc:0.971788
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][51]	validation_0-auc:0.973334
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][52]	validation_0-auc:0.973537
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][53]	validation_0-auc:0.973772
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][54]	validation_0-auc:0.973826
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][55]	validation_0-auc:0.973202
#
#  90%|█████████ | 9/10 [04:22<00:27, 27.02s/it, best loss: 4716954.2][56]	validation_0-auc:0.974513
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][57]	validation_0-auc:0.975208
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][58]	validation_0-auc:0.975708
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][59]	validation_0-auc:0.975809
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][60]	validation_0-auc:0.976387
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][61]	validation_0-auc:0.976598
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][62]	validation_0-auc:0.977066
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][63]	validation_0-auc:0.980786
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][64]	validation_0-auc:0.981247
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][65]	validation_0-auc:0.981106
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][66]	validation_0-auc:0.981427
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][67]	validation_0-auc:0.980779
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][68]	validation_0-auc:0.981028
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][69]	validation_0-auc:0.981185
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][70]	validation_0-auc:0.981559
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][71]	validation_0-auc:0.981895
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][72]	validation_0-auc:0.98394
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][73]	validation_0-auc:0.984674
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][74]	validation_0-auc:0.9854
#
#  90%|█████████ | 9/10 [04:23<00:27, 27.02s/it, best loss: 4716954.2][75]	validation_0-auc:0.984815
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][76]	validation_0-auc:0.984682
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][77]	validation_0-auc:0.986267
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][78]	validation_0-auc:0.986103
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][79]	validation_0-auc:0.985689
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][80]	validation_0-auc:0.985986
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][81]	validation_0-auc:0.98583
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][82]	validation_0-auc:0.985884
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][83]	validation_0-auc:0.987313
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][84]	validation_0-auc:0.988133
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][85]	validation_0-auc:0.987961
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][86]	validation_0-auc:0.987797
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][87]	validation_0-auc:0.988234
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][88]	validation_0-auc:0.987938
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][89]	validation_0-auc:0.988063
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][90]	validation_0-auc:0.988211
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][91]	validation_0-auc:0.988609
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][92]	validation_0-auc:0.988398
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][93]	validation_0-auc:0.988945
#
#  90%|█████████ | 9/10 [04:24<00:27, 27.02s/it, best loss: 4716954.2][94]	validation_0-auc:0.989187
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][95]	validation_0-auc:0.989171
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][96]	validation_0-auc:0.989515
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][97]	validation_0-auc:0.989749
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][98]	validation_0-auc:0.989936
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][99]	validation_0-auc:0.989523
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2]score en evaluate_model_with_slag_days
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2]7019253
# 4it [00:21,  5.29s/it]
#
# kfold 4
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][0]	validation_0-auc:0.903058
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][1]	validation_0-auc:0.903582
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][2]	validation_0-auc:0.907642
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][3]	validation_0-auc:0.910704
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][4]	validation_0-auc:0.956111
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][5]	validation_0-auc:0.961476
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][6]	validation_0-auc:0.962112
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][7]	validation_0-auc:0.96383
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][8]	validation_0-auc:0.963769
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][9]	validation_0-auc:0.963992
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][10]	validation_0-auc:0.964393
#
#  90%|█████████ | 9/10 [04:25<00:27, 27.02s/it, best loss: 4716954.2][11]	validation_0-auc:0.966195
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][12]	validation_0-auc:0.971823
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][13]	validation_0-auc:0.972096
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][14]	validation_0-auc:0.97301
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][15]	validation_0-auc:0.974689
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][16]	validation_0-auc:0.974656
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][17]	validation_0-auc:0.97445
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][18]	validation_0-auc:0.975509
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][19]	validation_0-auc:0.976045
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][20]	validation_0-auc:0.976764
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][21]	validation_0-auc:0.976909
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][22]	validation_0-auc:0.976803
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][23]	validation_0-auc:0.978253
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][24]	validation_0-auc:0.97919
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][25]	validation_0-auc:0.979413
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][26]	validation_0-auc:0.979492
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][27]	validation_0-auc:0.980088
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][28]	validation_0-auc:0.980217
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][29]	validation_0-auc:0.980083
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][30]	validation_0-auc:0.980585
#
#  90%|█████████ | 9/10 [04:26<00:27, 27.02s/it, best loss: 4716954.2][31]	validation_0-auc:0.984522
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][32]	validation_0-auc:0.98527
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][33]	validation_0-auc:0.98551
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][34]	validation_0-auc:0.985209
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][35]	validation_0-auc:0.985632
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][36]	validation_0-auc:0.985956
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][37]	validation_0-auc:0.986424
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][38]	validation_0-auc:0.985075
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][39]	validation_0-auc:0.987105
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][40]	validation_0-auc:0.988856
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][41]	validation_0-auc:0.989258
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][42]	validation_0-auc:0.988979
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][43]	validation_0-auc:0.989425
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][44]	validation_0-auc:0.989682
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][45]	validation_0-auc:0.990083
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][46]	validation_0-auc:0.99044
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][47]	validation_0-auc:0.990507
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][48]	validation_0-auc:0.990942
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][49]	validation_0-auc:0.991098
#
#  90%|█████████ | 9/10 [04:27<00:27, 27.02s/it, best loss: 4716954.2][50]	validation_0-auc:0.991522
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][51]	validation_0-auc:0.990853
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][52]	validation_0-auc:0.991009
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][53]	validation_0-auc:0.992493
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][54]	validation_0-auc:0.992839
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][55]	validation_0-auc:0.993218
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][56]	validation_0-auc:0.993329
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][57]	validation_0-auc:0.993296
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][58]	validation_0-auc:0.992995
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][59]	validation_0-auc:0.99382
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][60]	validation_0-auc:0.993831
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][61]	validation_0-auc:0.994132
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][62]	validation_0-auc:0.9943
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][63]	validation_0-auc:0.995003
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][64]	validation_0-auc:0.994969
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][65]	validation_0-auc:0.995047
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][66]	validation_0-auc:0.995471
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][67]	validation_0-auc:0.995806
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][68]	validation_0-auc:0.996051
#
#  90%|█████████ | 9/10 [04:28<00:27, 27.02s/it, best loss: 4716954.2][69]	validation_0-auc:0.995984
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][70]	validation_0-auc:0.99623
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][71]	validation_0-auc:0.996274
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][72]	validation_0-auc:0.996508
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][73]	validation_0-auc:0.996732
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][74]	validation_0-auc:0.996743
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][75]	validation_0-auc:0.996921
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][76]	validation_0-auc:0.996932
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][77]	validation_0-auc:0.99701
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][78]	validation_0-auc:0.997133
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][79]	validation_0-auc:0.997189
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][80]	validation_0-auc:0.997144
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][81]	validation_0-auc:0.997301
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][82]	validation_0-auc:0.997345
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][83]	validation_0-auc:0.997379
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][84]	validation_0-auc:0.997323
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][85]	validation_0-auc:0.997412
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][86]	validation_0-auc:0.997468
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][87]	validation_0-auc:0.997602
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][88]	validation_0-auc:0.997669
#
#  90%|█████████ | 9/10 [04:29<00:27, 27.02s/it, best loss: 4716954.2][89]	validation_0-auc:0.997591
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][90]	validation_0-auc:0.997646
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][91]	validation_0-auc:0.997646
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][92]	validation_0-auc:0.997613
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][93]	validation_0-auc:0.997657
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][94]	validation_0-auc:0.99768
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][95]	validation_0-auc:0.997791
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][96]	validation_0-auc:0.997847
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][97]	validation_0-auc:0.997825
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][98]	validation_0-auc:0.997858
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2][99]	validation_0-auc:0.997858
#
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2]score en evaluate_model_with_slag_days
#  90%|█████████ | 9/10 [04:30<00:27, 27.02s/it, best loss: 4716954.2]3188506
# 5it [00:26,  5.28s/it]
#
# 5it [00:26,  5.29s/it]
# [7000000, 4627012, 1750000, 7019253, 3188506]
# 100%|██████████| 10/10 [04:30<00:00, 27.06s/it, best loss: 4716954.2]
# best:
# {'colsample_bytree': 0.48, 'gamma': 0.11, 'learning_rate': 0.36, 'max_depth': 10, 'min_child_weight': 9.0, 'n_estimators': 8, 'scale_pos_weight': 0.5753069149377273, 'subsample': 0.23}

# %%
best_params_con_auc = {'colsample_bytree': 0.48, 'gamma': 0.11, 'learning_rate': 0.36, 'max_depth': 10, 'min_child_weight': 9.0, 'n_estimators': 8, 'scale_pos_weight': 0.5753069149377273, 'subsample': 0.23}

# %%
best['objective'] = 'binary:logistic'
params= best_params_con_auc
xgb = XGBClassifier(**params) #'multi:softprob')

X_test_attributes = [x for x in X_test.columns if x not in ['DAYS_TILL_SLAG']]

eval_set = [(X_test[X_test_attributes], y_test)]
global days_until_slag
days_until_slag = X_test['DAYS_TILL_SLAG']

xgb_best_params = xgb.fit(X_train[X_test_attributes], y_train, eval_metric='auc', eval_set=eval_set, verbose=True)        
              
best_params_xgb_predictions = xgb_best_params.predict(X_test[X_test_attributes])
print('with eval_metric = {}'.format('auc'))
confusion_matrix(y_test, best_params_xgb_predictions)
# Out:
# [0]	validation_0-auc:0.785219
# [1]	validation_0-auc:0.892589
# [2]	validation_0-auc:0.940233
# [3]	validation_0-auc:0.949265
# [4]	validation_0-auc:0.949067
# [5]	validation_0-auc:0.945188
# [6]	validation_0-auc:0.949082
# [7]	validation_0-auc:0.962041
# with eval_metric = return_edp_savings_function
# array([[1650,    1],
#        [  56,   50]], dtype=int64)

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, best_params_xgb_predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True)

# %% [markdown]
# ## Al parecer, evaluar con la función de coste EDP customizada aporta un recall mucho mayor

# %%
best_params_auc_eval_results_df = pd.DataFrame({'y_true_values': y_test, 'y_predicted_values': best_params_xgb_predictions})
best_params_auc_eval_results_df[best_params_auc_eval_results_df.y_predicted_values==1]
# Out:
#              y_true_values  y_predicted_values
# ID_sampling
# 10-11-09                 1                   1
# 10-18-22                 1                   1
# 10-06-07                 1                   1
# 10-06-04                 1                   1
# 10-20-10                 1                   1
# 10-05-10                 1                   1
# 10-24-04                 1                   1
# 10-21-00                 1                   1
# 10-20-06                 1                   1
# 10-21-02                 1                   1
# 10-10-22                 1                   1
# 10-19-18                 1                   1
# 10-21-16                 1                   1
# 10-19-00                 1                   1
# 10-17-08                 1                   1
# 10-16-01                 1                   1
# 10-11-03                 1                   1
# 10-17-13                 1                   1
# 10-15-12                 1                   1
# 10-19-20                 1                   1
# 06-13-09                 0                   1
# 10-15-06                 1                   1
# 10-11-05                 1                   1
# 10-13-04                 1                   1
# 10-17-09                 1                   1
# 10-08-02                 1                   1
# 10-25-07                 1                   1
# 10-18-01                 1                   1
# 10-05-23                 1                   1
# 10-20-18                 1                   1
# 10-14-01                 1                   1
# 10-21-19                 1                   1
# 10-17-07                 1                   1
# 10-11-02                 1                   1
# 10-19-04                 1                   1
# 10-16-17                 1                   1
# 10-25-02                 1                   1
# 10-21-18                 1                   1
# 10-07-06                 1                   1
# 10-06-23                 1                   1
# 10-09-02                 1                   1
# 10-09-04                 1                   1
# 10-21-21                 1                   1
# 10-18-02                 1                   1
# 10-17-02                 1                   1
# 10-11-17                 1                   1
# 10-06-02                 1                   1
# 10-05-16                 1                   1
# 10-11-16                 1                   1
# 10-19-06                 1                   1
# 10-22-00                 1                   1

# %% [markdown]
# # COMPROBAR SI CUMPLE BIEN EL BREAK EN CASO DE DETECTAR POSITIVO A TIEMPO

# %% [markdown]
# ## POC HIPEROPT: espero que simplemente encuentre el mínimo de las función de coste 'loss' x**2

# %%
def assign_prediction_to_proba(clf_prediction_proba):
    preds_dict = {'preds_probas': clf_prediction_proba, 'class': list(range(0, len(clf_prediction_proba)))}
    if preds_dict['preds_probas'][0] < 0.6:
        selected_proba = np.max(clf_prediction_proba[1:])
        final_prediction = preds_dict[preds_dict['preds_probas']==selected_proba]['class']
    
    return prediction
